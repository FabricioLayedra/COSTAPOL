# %%
import pandas as pd
import simplejson as json
import unicodedata
import matplotlib.pyplot as plt
from os import listdir

# %%
num_tweets = 0
invalid_tweets = 0
for fil in fils:
    name = path + fil
    g = json.loads(open(name).read())
    ###condicion de que sea retweet
    tweets = g["tweets"]
    num_tweets += g["num_tweets"]
    for tweet in tweets:
        if isValid(tweet) :
            invalid_tweets +=1
print num_tweets, invalid_tweets
# Out:
# 175587 175417

# %%
frequency_file = open("../Outputs/frequencies.csv","w")
frequency_file.write("user,num_tweets,num_vtweets,num_rts,num_favs\n")
mentioned = dict()
hashtags = dict()

for fil in fils:
    g = json.loads(open(fil).read())

    num_tweets = g["num_tweets"]
    tweets = g["tweets"]
    user = fil.split("/")[3].split(".")[0]
    valids = 0
    nrts = 0
    nfavs = 0
    mentioned[user]= set()
    hashtags[user]= dict()
    for tweet in tweets:
        valid = True
        for url in tweet["entities"]["urls"]:
            print url["display_url"]
            if url["display_url"] == "fllwrs.com":
                valid = False  
                print "entro"
        if valid :
            nrts += tweet["retweet_count"]
            nfavs += tweet["favorite_count"]
            valids +=1
            for mention in tweet["entities"]["user_mentions"]:
                s = mention["screen_name"]
                d = ''.join((c for c in unicodedata.normalize('NFD', unicode(s)) if unicodedata.category(c) != 'Mn'))
                mentioned[user].add(d)
            for hashtag in tweet["entities"]["hashtags"]:
                s = hashtag["text"]
                d = ''.join((c for c in unicodedata.normalize('NFD', unicode(s)) if unicodedata.category(c) != 'Mn'))
                if d in hashtags[user]:
                    hashtags[user][d] +=1
                else:
                    hashtags[user][d] = 1
    frequency_file.write("%s,%d,%d,%d,%d\n"%(user,num_tweets,valids,nrts,nfavs))
    for user in mentioned:
        mentions_file = open("../Outputs/mentions/%s_mentions.csv"%user,"w")
        mentions_file.write("user,mentioned_user")
        
        for mention in mentioned[user]:
            mentions_file.write("%s,%s\n"%(user,mention))
        mentions_file.close()
    for user in hashtags:
        hashtags_file = open("../Outputs/hashtags/%s_mentions.csv"%user,"w")
        hashtags_file.write("hashtag,frequency\n")
        
        for hashtag,freq in hashtags[user].items():
            hashtag = str(hashtag)
            freq= str(freq)
            linet = hashtag + "," + freq + "\n"
            hashtags_file.write(linet)
        hashtags_file.close()             
frequency_file.close()
# Out:
# bit.ly/2iu6oT7
# bit.ly/2xaXGvx
# presidencia.gob.ec
# goo.gl/kAwzmq
# youtube.com/watch?v=M2BqFq…
# presidencia.gob.ec
# bit.ly/2gxFQjn
# bit.ly/2qdhqhC
# twitter.com/i/web/status/9…
# goo.gl/3xjv1N
# twitter.com/i/web/status/9…
# twitter.com/i/web/status/9…
# goo.gl/yxgfWB
# goo.gl/MKQZy8
# goo.gl/S6RDoh
# twitter.com/i/web/status/9…
# pscp.tv/w/bLOaqTFXTEtS…
# goo.gl/Y4hXDu
# goo.gl/sgJzep
# twitter.com/gobermanabi/st…
# bit.ly/2g1NazM
# bit.ly/2i3YTBW
# bit.ly/2ydFlPT
# radioelite997.com/web/
# tinyurl.com/y75rxwsc
# bit.ly/2ybDjj5
# bit.ly/2wLN5qL
# bit.ly/2i250Hh
# bit.ly/2ycwEa4
# bit.ly/2gr1S3O
# goo.gl/hKgvW4
# twitter.com/i/web/status/9…
# twitter.com/i/web/status/9…
# turismo.gob.ec/ministerio-de-…
# bit.ly/1FIohk8
# m.luxurytraveladvisor.com/trends-researc…
# bit.ly/Promo303
# instagram.com/p/2IQzV2BY4p/
# instagram.com/p/2HuE7QhY4y/
# tvmanabita.tv
# instagram.com/p/2GtrJHBY49/
# instagram.com/p/2Gp3qKhYyB/
# twitter.com/ectv_noticias/…
# instagram.com/p/2FXWxbBYze/
# wp.me/p491HI-euW
# twitter.com/fanderfalconi/…
# twitter.com/mashirafael/st…
# twitter.com/telesurtv/stat…
# bit.ly/1dg4JZm
# twitter.com/ecu911sdt/stat…
# twitter.com/elciudadano_ec…
# elcomercio.com/actualidad/cam…
# bit.ly/1GsSa6C
# bit.ly/1K9PQ5F
# servicios.turismo.gob.ec/index.php/port…
# instagram.com/p/13Pek-hY-z/
# bit.ly/1Dp1bKs
# goo.gl/alerts/VR6C
# instagram.com/p/11PhzYBY_j/
# goo.gl/EjJeB7
# bit.ly/1K504UQ
# worldtravelawards.com/vote
# youtube.com/watch?v=p4mrC1…
# ow.ly/LMIQQ
# twitter.com/ecuainm/status…
# lastanusas.blogspot.com/2015/04/parais…

# %%
fils = listdir("../Data/timeline/manta/")
path = "../Data/timeline/manta/"

def isRetweet(tweet):
	texto = tweet['text']
	if 'retweeted_status' in tweet or (len(texto) > 4 and texto[:4] == 'RT @'):
		return True
	return False

def isValid(tweet):
    for url in tweet["entities"]["urls"]:
        #print url["display_url"]
        if url["display_url"] == "fllwrs.com":
            return False 
    return True

# %%
mentions_file = open("../Outputs/mentions.csv","w")
mentions_file.write("source,target,weight\n")

mentions = dict()
for fil in fils:
    name = path + fil
    g = json.loads(open(name).read())
    ###condicion de que sea retweet
    num_tweets = g["num_tweets"]
    tweets = g["tweets"]
    user = name.split("/")[4].split(".")[0]
    valids = 0
    for tweet in tweets:
        if isValid(tweet) and isRetweet(tweet):
            #print tweet
            for people in tweet["entities"]["user_mentions"]:
                if (user,people["screen_name"]) in mentions:
                    mentions[user,(people["screen_name"])] +=1
                else:
                    mentions[user,(people["screen_name"])] =1

for mention in mentions:
    source,target = mention
    mentions_file.write(source + ","+ target + ","+ str(mentions[mention])+"\n")
mentions_file.close()

# %%
hashtags_file = open("../Outputs/hashtags.csv","w")
hashtags_file.write("user,hashtag,frequency\n")

hashtags = dict()
for fil in fils:
    name = path + fil
    g = json.loads(open(name).read())
    ###condicion de que sea retweet
    num_tweets = g["num_tweets"]
    tweets = g["tweets"]
    user = name.split("/")[4].split(".")[0]
    valids = 0
    hashtags[user]= dict()
    for tweet in tweets:
        if isValid(tweet):
            #print tweet
            for hashtag in tweet["entities"]["hashtags"]:
                s = hashtag["text"]
                #print s
                d = ''.join((c for c in unicodedata.normalize('NFD', unicode(s)) if unicodedata.category(c) != 'Mn'))
                if d in hashtags[user]:
                    hashtags[user][d] +=1
                else:
                    hashtags[user][d] = 1
                    #print hashtags[user]

for user in hashtags:
    for hashtag in hashtags[user]:
        freq = hashtags[user][hashtag]
        line = user+ ","+ hashtag + ","+ str(freq)+"\n"
        print line
        hashtags_file.write(line)
hashtags_file.close()
# Out:
# APortuariaManta,DiaDeLaBandera,3
#
# APortuariaManta,TPMInforma,2
#
# APortuariaManta,OrgulloEcuatoriano,1
#
# APortuariaManta,SeguridadVialEc,5
#
# APortuariaManta,DiaMundialdelTurismo,1
#
# APortuariaManta,FelizDiaDelTrabajador,1
#
# APortuariaManta,UsaBienEl911,1
#
# APortuariaManta,Financiamiento,1
#
# APortuariaManta,PostalECU911,1
#
# APortuariaManta,EnManabi,1
#
# APortuariaManta,ManabiVial,1
#
# APortuariaManta,BuenViernes,1
#
# APortuariaManta,EcuadorNiUnaMenos,5
#
# APortuariaManta,NuestraConstitucionEC,8
#
# APortuariaManta,ElSaborDeManabi,1
#
# APortuariaManta,VacacionesSeguras,2
#
# APortuariaManta,Calle13,1
#
# APortuariaManta,TrabajamosPorManabi,1
#
# APortuariaManta,MANTA,4
#
# APortuariaManta,Sismo,1
#
# APortuariaManta,ObrasParaTodos,9
#
# APortuariaManta,DiaMundialDelTurismo,6
#
# APortuariaManta,LeydePesca,2
#
# APortuariaManta,SismoEcuador,5
#
# APortuariaManta,10DeAgosto,1
#
# APortuariaManta,76anosARE,1
#
# APortuariaManta,SeguridadySaludOcupacional,1
#
# APortuariaManta,Familia,1
#
# APortuariaManta,NuestraConstitucionEc,1
#
# APortuariaManta,Manabi,84
#
# APortuariaManta,puerto,1
#
# APortuariaManta,MuellesInternacionales,1
#
# APortuariaManta,FelizMiercoles,6
#
# APortuariaManta,SilverMuse,1
#
# APortuariaManta,TuriDestacados,1
#
# APortuariaManta,TerminalDePasajeros,1
#
# APortuariaManta,SPTMF,2
#
# APortuariaManta,PrimerPiloteTPM,1
#
# APortuariaManta,MinturTalks,1
#
# APortuariaManta,CursosPatonato,1
#
# APortuariaManta,HRZ,1
#
# APortuariaManta,ApmElCorazonDeManta,26
#
# APortuariaManta,maquillaje,1
#
# APortuariaManta,TPM,30
#
# APortuariaManta,ironmanEc,1
#
# APortuariaManta,ObrasParaManta,2
#
# APortuariaManta,BotonDeSeguridad,1
#
# APortuariaManta,InvestEcuador,2
#
# APortuariaManta,ReinaDeManta2017,1
#
# APortuariaManta,TravelEnjoyRespect,1
#
# APortuariaManta,FuerzaMexico,3
#
# APortuariaManta,Jama,1
#
# APortuariaManta,LaTrataEsUnDelito,1
#
# APortuariaManta,laser,1
#
# APortuariaManta,Junio,3
#
# APortuariaManta,NiUnaMenos,1
#
# APortuariaManta,3RuedaDeNegocios,1
#
# APortuariaManta,DiaDeLasMdres,1
#
# APortuariaManta,GoberManabi,2
#
# APortuariaManta,VideovigilanciaECU911,2
#
# APortuariaManta,Deltas,1
#
# APortuariaManta,Instagram,1
#
# APortuariaManta,HOY,1
#
# APortuariaManta,MesDelManabitismo,7
#
# APortuariaManta,fomix,1
#
# APortuariaManta,EcuadorSinTabaco,1
#
# APortuariaManta,DiaDelChoferEcuatoriano,1
#
# APortuariaManta,UtilizaSombreroEcuador,1
#
# APortuariaManta,FeriadoSeguro,39
#
# APortuariaManta,VenAGuayaquil,1
#
# APortuariaManta,FelizViernes,5
#
# APortuariaManta,Tributacion,1
#
# APortuariaManta,ServiciosANT,3
#
# APortuariaManta,PAC,1
#
# APortuariaManta,MecanicaAutomotriz,1
#
# APortuariaManta,Crucero,1
#
# APortuariaManta,FelizMartes,4
#
# APortuariaManta,yosoyApm,1
#
# APortuariaManta,Murcielago,1
#
# APortuariaManta,RegeneracionUrbana,1
#
# APortuariaManta,Belleza,1
#
# APortuariaManta,Malecon,1
#
# APortuariaManta,IROMAN,1
#
# APortuariaManta,Manabi193Anos,1
#
# APortuariaManta,DialogoNacional,4
#
# APortuariaManta,FelizDiaDelServidorPublico,1
#
# APortuariaManta,AlcadiaDeManta,1
#
# APortuariaManta,Gestion2016,1
#
# APortuariaManta,RecomendacionHRZ,4
#
# APortuariaManta,IromanEc,1
#
# APortuariaManta,FelizJueves,3
#
# APortuariaManta,Vialito,2
#
# APortuariaManta,Aneta,1
#
# APortuariaManta,ObrasSonDesarrollo,5
#
# APortuariaManta,AbrilMesDelLibro,1
#
# APortuariaManta,Maquillaje,1
#
# APortuariaManta,Hoy,1
#
# APortuariaManta,ObrasParaElPuerto,1
#
# APortuariaManta,AvistamientoDeBallenas,5
#
# APortuariaManta,FelizNoche,2
#
# APortuariaManta,Naval,1
#
# APortuariaManta,Tarqui,2
#
# APortuariaManta,manabita,1
#
# APortuariaManta,Manta,459
#
# APortuariaManta,MantaEspectacular,1
#
# APortuariaManta,Mexico,6
#
# APortuariaManta,JEEP,1
#
# APortuariaManta,Respetoalpeaton,2
#
# APortuariaManta,FelizSabado,2
#
# APortuariaManta,Terremoto16A,1
#
# APortuariaManta,DiaSinAuto,14
#
# APortuariaManta,AmpliacionMuelleManta,1
#
# APortuariaManta,MiBanderaEC,1
#
# APortuariaManta,RiesgosDelTrabajo,1
#
# APortuariaManta,1DeMayo,1
#
# APortuariaManta,GestionDelegada,1
#
# APortuariaManta,EcuadorConGlas,1
#
# APortuariaManta,FelizDiaDelPadre,1
#
# APortuariaManta,SeguridadVial,1
#
# APortuariaManta,viernes,1
#
# APortuariaManta,PuertoAltamira,1
#
# APortuariaManta,SimonBolivar,1
#
# APortuariaManta,SISMO,1
#
# APortuariaManta,PactoPorLaVida,1
#
# APortuariaManta,RespetoAlPeaton,1
#
# APortuariaManta,APM,70
#
# APortuariaManta,Ahora,1
#
# APortuariaManta,MantaProgresa,8
#
# APortuariaManta,RocioDeMoreno,1
#
# APortuariaManta,FelizDiaDelNino,1
#
# APortuariaManta,ParrilladaDeMariscos,1
#
# APortuariaManta,Barbershop,2
#
# APortuariaManta,ApmEnLaHistoria,2
#
# APortuariaManta,AfectadosCasoOGC,1
#
# APortuariaManta,AllYouNeedIsEcuador,2
#
# APortuariaManta,Iran,1
#
# APortuariaManta,PorTuSeguridad,9
#
# APortuariaManta,sismo,4
#
# APortuariaManta,LluviasEc,3
#
# APortuariaManta,Ironman70,1
#
# APortuariaManta,SER,2
#
# APortuariaManta,DiaMundialSinAuto,1
#
# APortuariaManta,TerminaldePasajerosInternacional,1
#
# APortuariaManta,GADManabiRecomienda,1
#
# APortuariaManta,CTEPresente,1
#
# APortuariaManta,AtencionCiudadana,1
#
# APortuariaManta,AurelioHidalgo,1
#
# APortuariaManta,telas,1
#
# APortuariaManta,UnionEuropea,1
#
# APortuariaManta,IromanManta2017,1
#
# APortuariaManta,PrimerCuatrimestreTPM,1
#
# APortuariaManta,FeriadoSemanaSanta,3
#
# APortuariaManta,SeguridadInternet,1
#
# APortuariaManta,Tungurahua,1
#
# APortuariaManta,Diccionario,1
#
# APortuariaManta,EmmaPatriciaAguilar,1
#
# APortuariaManta,BuenasNoticias,1
#
# APortuariaManta,ANTManabi,1
#
# APortuariaManta,DiaDelTrabajador,3
#
# APortuariaManta,FeriadoProvincial,7
#
# APortuariaManta,ENVIVO,1
#
# APortuariaManta,SubastaEnLineaEc,1
#
# APortuariaManta,10Oct,1
#
# APortuariaManta,Paquito,2
#
# APortuariaManta,VamosSuave,69
#
# APortuariaManta,20deMayo,1
#
# APortuariaManta,SemanaSanta,44
#
# APortuariaManta,ObrasTodaUnaVida,16
#
# APortuariaManta,GestionSostenibleEC,1
#
# APortuariaManta,HRZTeCuida,1
#
# APortuariaManta,Automaquillaje,1
#
# APortuariaManta,ManejaSeguro,167
#
# APortuariaManta,PactoVialEC,1
#
# APortuariaManta,Internacionalizate,1
#
# APortuariaManta,OrgullosamenteManabita,2
#
# APortuariaManta,ironman,1
#
# APortuariaManta,enfermeria,1
#
# APortuariaManta,MunicipioDigital,1
#
# APortuariaManta,DiaDeLaMadre,1
#
# APortuariaManta,FilmCommissionEc,2
#
# APortuariaManta,Ecuador,72
#
# APortuariaManta,TuFeriadoEnManabi,1
#
# APortuariaManta,MangaDelCura,1
#
# APortuariaManta,ApmOfficialPartner,3
#
# APortuariaManta,FelizLunes,5
#
# APortuariaManta,LaSaludJuntoati,1
#
# APortuariaManta,TemporadaDeCruceros,2
#
# APortuariaManta,MTOPInforma,173
#
# APortuariaManta,PuertodeManta,10
#
# APortuariaManta,FelizDomingo,2
#
# APortuariaManta,16A,2
#
# APortuariaManta,FelizDiaPapa,1
#
# APortuariaManta,SeaPrincess,1
#
# APortuariaManta,ConsejoProductivoTributario,1
#
# APortuariaManta,DiaMundialMaritimo,1
#
# APortuariaManta,PactoVialEc,243
#
# APortuariaManta,RendicionDeCuentas2016,1
#
# APortuariaManta,ULEAM,4
#
# APortuariaManta,AMERICA,1
#
# APortuariaManta,MuellePesquero,2
#
# APortuariaManta,VenAManabiTeEspero,12
#
# APortuariaManta,SRIzonal4,1
#
# APortuariaManta,Costura,1
#
# APortuariaManta,Inversion,1
#
# APortuariaManta,Felizlunes,1
#
# APortuariaManta,InicioOficialOperacionesTPM,1
#
# APortuariaManta,TemporadadeCruceros,1
#
# APortuariaManta,Daquilema,18
#
# APortuariaManta,manualidades,1
#
# APortuariaManta,Portuaria,2
#
# APortuariaManta,Galapagos,1
#
# APortuariaManta,DiaMundialdelTurismo2017,1
#
# APortuariaManta,Portoviejo,4
#
# APortuariaManta,diamundialsinauto,1
#
# APortuariaManta,NOTICIAIMPORTANTE,1
#
# APortuariaManta,Cross,1
#
# APortuariaManta,AromasDelEcuador,1
#
# APortuariaManta,Proactividad,1
#
# APortuariaManta,TerminalDeCruceros,6
#
# APortuariaManta,Manana,1
#
# APortuariaManta,MTOP,29
#
# APortuariaManta,Babahoyo,1
#
# APortuariaManta,CuidaTuVida,1
#
# APortuariaManta,CorreosDelEcuador,1
#
# APortuariaManta,TameEP,1
#
# APortuariaManta,CancerDeMama,1
#
# APortuariaManta,DeVueltaAlCole,12
#
# APortuariaManta,EdisonPerez,1
#
# APortuariaManta,OrgullosamenteManabitas,1
#
# APortuariaManta,PrimeraPiedraTPC,2
#
# APortuariaManta,EcuadorDestinoSeguro,8
#
# APortuariaManta,Uruguay,1
#
# APortuariaManta,portuaria,2
#
# APortuariaManta,AAPA2017,1
#
# APortuariaManta,CineEnLaPlaya,1
#
# APortuariaManta,Manabitismo,3
#
# APortuariaManta,GralRamos,1
#
# APortuariaManta,ECU911Conmigo,14
#
# APortuariaManta,NoPescaIlegal,1
#
# APortuariaManta,AeropuertoDeManta,2
#
# APortuariaManta,proactivo,1
#
# APortuariaManta,PrimerosAuxilios,1
#
# APortuariaManta,SomosPeatones,4
#
# APortuariaManta,ManabiMarket,1
#
# APortuariaManta,LaSaludJuntoaTi,3
#
# APortuariaManta,IronManEC,6
#
# APortuariaManta,PuertoLopez,1
#
# APortuariaManta,DiaMundialDeLaBicicleta,2
#
# APortuariaManta,MantaDigital,1
#
# APortuariaManta,Zona4Ec,4
#
# APortuariaManta,Hoteleria,1
#
# APortuariaManta,LaConsultaVa,4
#
# APortuariaManta,Loja,1
#
# APortuariaManta,SeguridadCiudadana,1
#
# APortuariaManta,Trabajamos24,15
#
# APortuariaManta,ViveElFeriadoEc,1
#
# APortuariaManta,SesionSolemne,1
#
# APortuariaManta,Atentos,7
#
# APortuariaManta,AHORA,1
#
# APortuariaManta,ParVial,2
#
# APortuariaManta,conservacion,1
#
# APortuariaManta,Terminal,1
#
# APortuariaManta,AgendaGubernamental,1
#
# APortuariaManta,Montecristi,3
#
# APortuariaManta,DiaDeLasMadres,4
#
# APortuariaManta,TRIATHLON,1
#
# APortuariaManta,9Oct,1
#
# APortuariaManta,Iroman,2
#
# APortuariaManta,Viernes,1
#
# APortuariaManta,Navidad,1
#
# APortuariaManta,ViasECU911,2
#
# APortuariaManta,belleza,1
#
# APortuariaManta,Maritima,2
#
# APortuariaManta,JuntosNosCuidamos,1
#
# APortuariaManta,DiaDelPadre,1
#
# APortuariaManta,SemanaDelMar,4
#
# APortuariaManta,PortalCiudadano,1
#
# APortuariaManta,ModelosDeGestion,1
#
# APortuariaManta,WashingtonLeon,1
#
# APortuariaManta,Feriado,3
#
# APortuariaManta,Ironman,62
#
# APortuariaManta,DiaInternacionalDeLaPaz,1
#
# APortuariaManta,maritima,2
#
# APortuariaManta,IronmanEc,6
#
# APortuariaManta,CuidandoDeTi,1
#
# APortuariaManta,YoLeoEc,1
#
# APortuariaManta,DiaMundialSinTabaco,1
#
# APortuariaManta,TemporadaDeCrucero,1
#
# APortuariaManta,DiaDeLaInterculturalidad,1
#
# APortuariaManta,DiaDelNino,2
#
# APortuariaManta,PuertoDeManta,99
#
# APortuariaManta,ATENTOS,6
#
# APortuariaManta,CunaDeEmprendedores,1
#
# APortuariaManta,MaleconEsenico,4
#
# APortuariaManta,Jaramijo,2
#
# APortuariaManta,PrefectoMZ,1
#
# APortuariaManta,TerminalPortuaria,1
#
# APortuariaManta,IM703Ec,13
#
# APortuariaManta,ECU911,10
#
# APortuariaManta,AccionPorElPlaneta,4
#
# APortuariaManta,Esmeraldas,1
#
# APortuariaManta,ConoceMiPuerto,40
#
# APortuariaManta,PlayaMurcielago,38
#
# APortuariaManta,SanduchonSolidario,1
#
# APortuariaManta,CURSOSPATRONATO,1
#
# APortuariaManta,MaleconEscenico,459
#
# APortuariaManta,Cruceros,1
#
# APortuariaManta,SATEcuador,3
#
# APortuariaManta,PeatonSeguro,7
#
# APortuariaManta,CrnlZarate,1
#
# APortuariaManta,LeyDePesca,4
#
# APortuariaManta,FelizFinDeSemana,1
#
# APortuariaManta,terremoto,1
#
# APortuariaManta,Mtop,1
#
# APortuariaManta,InocarInforma,3
#
# APortuariaManta,DiaMundialSinAutos,2
#
# APortuariaManta,YoSoyAPM,2
#
# APortuariaManta,Facci,1
#
# APortuariaManta,RetornoSeguro,1
#
# APortuariaManta,AlcaldiaDeManta,2
#
# APortuariaManta,Urbirrios2,1
#
# manta360,oleajes,1
#
# manta360,EnEstosMomentos,1
#
# manta360,chile,1
#
# manta360,casaemergente,1
#
# manta360,hoyurgente,2
#
# manta360,TerremotoEcuador,8
#
# manta360,un15k,1
#
# manta360,Galapagos,3
#
# manta360,Muisne,1
#
# manta360,FelizDiaMama,1
#
# manta360,japon,2
#
# manta360,Peru,1
#
# manta360,tsunamiEC,4
#
# manta360,tsunamiec,32
#
# manta360,apagonManabi,1
#
# manta360,TsunamiEC,1
#
# manta360,ManabiSinLuz,1
#
# manta360,Ecuador,10
#
# manta360,Manta,47
#
# manta360,SeNecesitaEc,1
#
# manta360,ff,1
#
# manta360,PuertodeManta,1
#
# manta360,MantaFC,1
#
# manta360,TemblorEcuador,1
#
# manta360,Enlace476,1
#
# manta360,Manabisinluz,1
#
# manta360,SismoEcuador,11
#
# manta360,JuegosManta2011,1
#
# manta360,Calceta,1
#
# manta360,Pedernales,1
#
# manta360,Manabi,19
#
# manta360,ApagonManabi,2
#
# manta360,Xochimilco,1
#
# manta360,rutadelspondylus,1
#
# manta360,ManabiEsTodo,2
#
# manta360,BSC,1
#
# manta360,manta,7
#
# manta360,mozcation,1
#
# manta360,SISMO,5
#
# manta360,CasaEmergente,1
#
# manta360,Miami,1
#
# manta360,DesaparecidosEC,1
#
# manta360,EcuadorALevantarse,2
#
# manta360,SOS,1
#
# manta360,TerremotoenEcuador,1
#
# manta360,Tsunami,1
#
# manta360,ECuador,1
#
# manta360,CopaAmerica,1
#
# manta360,Jaramijo,1
#
# manta360,IIJSPManta2011,1
#
# manta360,FuerzaManta,1
#
# manta360,Deja,1
#
# manta360,Babahoyo,1
#
# manta360,MANABI,1
#
# manta360,ServiciosEc,4
#
# manta360,Calle13,1
#
# manta360,Tsunamiec,1
#
# manta360,wrestlemania,1
#
# manta360,Esmeraldas,3
#
# manta360,FF,1
#
# manta360,AaronCadena,1
#
# manta360,marejada,1
#
# manta360,tsunamiEc,4
#
# manta360,Aduanas,1
#
# manta360,delitosEC,1
#
# manta360,terremoto,3
#
# manta360,clasicodelastillero,1
#
# manta360,WM27,1
#
# manta360,parrilladaTwittera,1
#
# manta360,carnaval,1
#
# manta360,TerremotoEnEcuador,1
#
# manta360,EcuadorListoYSolidario,1
#
# manta360,tsunami,5
#
# manta360,Japon,1
#
# manta360,ecuador,1
#
# manta360,ecu911,1
#
# manta360,Emelec,2
#
# manta360,Correa,1
#
# UTMManabi,StoDomingo,1
#
# UTMManabi,IFTH,1
#
# UTMManabi,capitalnoticias,1
#
# UTMManabi,prefecto,2
#
# UTMManabi,Economicas,1
#
# UTMManabi,Becas,4
#
# UTMManabi,EncuentroDeTeatroUniversitario,1
#
# UTMManabi,Moon,1
#
# UTMManabi,Internacional,1
#
# UTMManabi,LeadersfortheWorld,1
#
# UTMManabi,chikungunya,1
#
# UTMManabi,uleam,1
#
# UTMManabi,Eventogratuito,1
#
# UTMManabi,MedidasPrevencion,2
#
# UTMManabi,TalleresParticipativos,1
#
# UTMManabi,MaraMolina,1
#
# UTMManabi,FacultadDeCienciasMatematicas,3
#
# UTMManabi,Mujer,1
#
# UTMManabi,universidadtecnicademanabi,2
#
# UTMManabi,pregon,1
#
# UTMManabi,iniciativa,1
#
# UTMManabi,NNA,1
#
# UTMManabi,primeraedicion,1
#
# UTMManabi,innovarParaTransformar,1
#
# UTMManabi,Octubremesdelasciencias,8
#
# UTMManabi,PrimerMinistrodeCanada,1
#
# UTMManabi,Manabi,39
#
# UTMManabi,veterinaria,1
#
# UTMManabi,Aniversario,1
#
# UTMManabi,Administrativas,1
#
# UTMManabi,MAESTRIA,1
#
# UTMManabi,sangregorio,1
#
# UTMManabi,MesdelManabitismo,3
#
# UTMManabi,EventoGratuito,1
#
# UTMManabi,salud,1
#
# UTMManabi,VUEPortoviejo,1
#
# UTMManabi,Maestria,1
#
# UTMManabi,Magap,1
#
# UTMManabi,ECONOMIA,1
#
# UTMManabi,seguimostrabajando,1
#
# UTMManabi,SeminarioDeOrdenamientoTerritorial,1
#
# UTMManabi,Claraboya,1
#
# UTMManabi,MANABI,3
#
# UTMManabi,UPSG,1
#
# UTMManabi,GoberManabi,1
#
# UTMManabi,manabitas,1
#
# UTMManabi,MesDelManabitismo,2
#
# UTMManabi,PoliticaIndustrial,1
#
# UTMManabi,VIH,1
#
# UTMManabi,ANMIG,1
#
# UTMManabi,YoHagoDeporte,1
#
# UTMManabi,pilas,3
#
# UTMManabi,Certificar,1
#
# UTMManabi,Enfermeria,1
#
# UTMManabi,yosoymanabacarajo,1
#
# UTMManabi,DistritosSalud,1
#
# UTMManabi,TrovandoenLunes,1
#
# UTMManabi,PANDA,1
#
# UTMManabi,Pontepilasconlaspilas,2
#
# UTMManabi,DialogoNacional,1
#
# UTMManabi,PortoviejoNaceDeTi,1
#
# UTMManabi,UTMACH,1
#
# UTMManabi,acuicultura,1
#
# UTMManabi,ManabiSeLevanta,1
#
# UTMManabi,universidades,1
#
# UTMManabi,planificacion,1
#
# UTMManabi,GabrielaEnManabi,11
#
# UTMManabi,bioquimicos,1
#
# UTMManabi,Peru,1
#
# UTMManabi,Docente,1
#
# UTMManabi,enlace396,3
#
# UTMManabi,CasaAbierta,1
#
# UTMManabi,Octubre,7
#
# UTMManabi,SilvioRodriguez,1
#
# UTMManabi,PresidentedeColombia,1
#
# UTMManabi,Cuba,1
#
# UTMManabi,Crucita,1
#
# UTMManabi,2docongresointernac,1
#
# UTMManabi,Ciencias,4
#
# UTMManabi,genetica,1
#
# UTMManabi,dengue,1
#
# UTMManabi,CineForoUTM,1
#
# UTMManabi,reforestacion,1
#
# UTMManabi,GiraAcademica,1
#
# UTMManabi,GALARDONES2015,2
#
# UTMManabi,octubre,2
#
# UTMManabi,seminario,3
#
# UTMManabi,MangaDelCura,1
#
# UTMManabi,MovilidadHumana,1
#
# UTMManabi,epidemiologia,1
#
# UTMManabi,simposios,1
#
# UTMManabi,HCU,1
#
# UTMManabi,BiodiversidadManabita,2
#
# UTMManabi,CineForo,1
#
# UTMManabi,ATENCION,1
#
# UTMManabi,pedagogia,1
#
# UTMManabi,Ecologicos,1
#
# UTMManabi,RendicionDeCuenta2014,1
#
# UTMManabi,Conferencia,3
#
# UTMManabi,LaMangadelCura,1
#
# UTMManabi,Dengue,2
#
# UTMManabi,MIDUVI,1
#
# UTMManabi,RelacionesLaborales,1
#
# UTMManabi,manabi,11
#
# UTMManabi,Manabiseproyecta,1
#
# UTMManabi,Enlace396,3
#
# UTMManabi,ambiente,1
#
# UTMManabi,alimentacion,1
#
# UTMManabi,seminarios,1
#
# UTMManabi,ENTUN,1
#
# UTMManabi,Inclusion,1
#
# UTMManabi,CarlosMarxCarrasco,1
#
# UTMManabi,premioOdebrechtEcuador,6
#
# UTMManabi,portoviejo,18
#
# UTMManabi,60Aniversario,6
#
# UTMManabi,Convencion,1
#
# UTMManabi,Artesanos,1
#
# UTMManabi,JorgeJurado,1
#
# UTMManabi,Envivo,1
#
# UTMManabi,universidad,2
#
# UTMManabi,CIAContraAmericaLatinaCasoEspecial,1
#
# UTMManabi,MinisteriosSectoriales,1
#
# UTMManabi,EncuentroDeTeatro,1
#
# UTMManabi,lenguajedesenas,1
#
# UTMManabi,SomosRevolucion,1
#
# UTMManabi,utmmanabi,2
#
# UTMManabi,ManabiEresTu,1
#
# UTMManabi,Manabitismo,3
#
# UTMManabi,PedroPaez,1
#
# UTMManabi,rendiciondecuentas,1
#
# UTMManabi,AIESEC,9
#
# UTMManabi,innovacion,1
#
# UTMManabi,ManabiSera,2
#
# UTMManabi,manuelsarmiento,1
#
# UTMManabi,reforestar,1
#
# UTMManabi,enfermeria,1
#
# UTMManabi,OrgAIESEC,1
#
# UTMManabi,Ecuador,1
#
# UTMManabi,nutricion,1
#
# UTMManabi,Anaqueronte,1
#
# UTMManabi,Zona4,1
#
# UTMManabi,SolidaridadMotorReconstruccion,1
#
# UTMManabi,PuertodeManta,1
#
# UTMManabi,ESPAM,1
#
# UTMManabi,FacultadMatematicas,1
#
# UTMManabi,EEUU,1
#
# UTMManabi,TodosporManabi,1
#
# UTMManabi,CasaAbiertas,1
#
# UTMManabi,ecuador,6
#
# UTMManabi,agricola,1
#
# UTMManabi,Educacion,1
#
# UTMManabi,agorindustria,1
#
# UTMManabi,LaEsclavitudDeAmericaLatina,1
#
# UTMManabi,Portoviejo,32
#
# UTMManabi,MatrizProductiva,1
#
# UTMManabi,conclusiones,1
#
# UTMManabi,clinico,1
#
# UTMManabi,RendicionDeCuentas,2
#
# UTMManabi,aniversario,1
#
# UTMManabi,Omep,1
#
# UTMManabi,Innova,1
#
# UTMManabi,Contables,1
#
# UTMManabi,educacion,1
#
# UTMManabi,JugandoaFotografo,1
#
# UTMManabi,agronomia,1
#
# UTMManabi,utm,8
#
# UTMManabi,Luna,1
#
# UTMManabi,LeyDeTierras,1
#
# UTMManabi,Chone,2
#
# UTMManabi,ordenamientoterritorial,14
#
# UTMManabi,UNESUM,2
#
# UTMManabi,amiigo,1
#
# UTMManabi,Bibliotecologia,1
#
# UTMManabi,Democracias,1
#
# UTMManabi,JefePolitico,2
#
# UTMManabi,inclusiva,1
#
# UTMManabi,ManabiEstaDeFiesta,1
#
# UTMManabi,Peace,1
#
# UTMManabi,congresos,1
#
# UTMManabi,CodigodelTrabajo,2
#
# UTMManabi,widderMacias,1
#
# UTMManabi,LOT,1
#
# UTMManabi,CongresoSaludSCPM,1
#
# UTMManabi,sociales,1
#
# UTMManabi,PortoviejoNacedeTi,1
#
# UTMManabi,humanisticas,1
#
# UTMManabi,Prefecto,2
#
# UTMManabi,Zambrano,1
#
# UTMManabi,ingles,1
#
# UTMManabi,LaVirtuddeloscomunes,1
#
# UTMManabi,SCPM,1
#
# UTMManabi,ElizabethMera,1
#
# UTMManabi,MIES,1
#
# UTMManabi,GAD,1
#
# UTMManabi,Cientifica,1
#
# UTMManabi,FeriaDeLaUTM,1
#
# UTMManabi,ABG,1
#
# UTMManabi,HablaManabi,2
#
# UTMManabi,ciclopaseo,1
#
# UTMManabi,ULEAM,1
#
# UTMManabi,UTM,41
#
# UTMManabi,VicenteVeliz,5
#
# UTMManabi,Agropecuarias,1
#
# UTMManabi,ECU911,1
#
# UTMManabi,RelacionesExteriores,1
#
# UTMManabi,MesaDeSeguridad,1
#
# UTMManabi,Copisa,1
#
# UTMManabi,Esmeraldas,1
#
# UTMManabi,SDG5,1
#
# UTMManabi,Chikungunya,2
#
# UTMManabi,FomentoProductivo,2
#
# UTMManabi,cesantiaSegura,1
#
# UTMManabi,AmericaLatina,1
#
# UTMManabi,Unesum,1
#
# UTMManabi,drone,1
#
# UTMManabi,Autoevaluacion,1
#
# UTMManabi,JuntosPorManabi,1
#
# UTMManabi,unesum,1
#
# UTMManabi,CongresoAgropecuario,10
#
# UTMManabi,preguntaleAsegundito,2
#
# smontenegro2923,Revolucion,5
#
# smontenegro2923,CadaVezSonMenos,1
#
# smontenegro2923,FranciscoenEc,1
#
# smontenegro2923,Balompiecuador,2
#
# smontenegro2923,SerieBxOromar,2
#
# smontenegro2923,DCuenca,1
#
# smontenegro2923,Sesion363,1
#
# smontenegro2923,Bolivar,2
#
# smontenegro2923,Habitat3,2
#
# smontenegro2923,LaRevolucionNoPara,1
#
# smontenegro2923,ProyectoMinero,1
#
# smontenegro2923,HospitalVerdiCevallos,1
#
# smontenegro2923,YoEsperoAlPapa,1
#
# smontenegro2923,ClasicoManaba,8
#
# smontenegro2923,Uruguayos,1
#
# smontenegro2923,Progreso,1
#
# smontenegro2923,VamosLDUP,11
#
# smontenegro2923,PaisUnidad,1
#
# smontenegro2923,Registro,1
#
# smontenegro2923,Enlace416,4
#
# smontenegro2923,Junin,2
#
# smontenegro2923,ElEquipo7,1
#
# smontenegro2923,LatinoamericaConDilma,1
#
# smontenegro2923,riobamba,2
#
# smontenegro2923,JuventudSolidaria,2
#
# smontenegro2923,LDUPortoviejo,1
#
# smontenegro2923,Manabi,105
#
# smontenegro2923,UnidosPodemos,1
#
# smontenegro2923,bloque35unido,1
#
# smontenegro2923,UnidosPodemosLDUP,3
#
# smontenegro2923,LIGADEPORTOVIEJO,1
#
# smontenegro2923,1roDeMayo,1
#
# smontenegro2923,AfiliacionAmasDeCasa,1
#
# smontenegro2923,VamosPorMas,1
#
# smontenegro2923,MCanar,3
#
# smontenegro2923,regional,1
#
# smontenegro2923,FrancisenEcuador,1
#
# smontenegro2923,LeyDeComunas,1
#
# smontenegro2923,UnPasoMasAcuerdoUE,1
#
# smontenegro2923,CDG,1
#
# smontenegro2923,Wolf,1
#
# smontenegro2923,FiscalizacionEnTerritorio,2
#
# smontenegro2923,MANABI,3
#
# smontenegro2923,solidaridad,1
#
# smontenegro2923,farra,1
#
# smontenegro2923,Riobamaba,1
#
# smontenegro2923,GoberManabi,5
#
# smontenegro2923,FinishClass,1
#
# smontenegro2923,FelizDiaDelPadre,1
#
# smontenegro2923,VamosVerdeYBlanco,1
#
# smontenegro2923,LAFOTO,1
#
# smontenegro2923,NoTeRindas,1
#
# smontenegro2923,LeyDePrevencionDeDrogas,1
#
# smontenegro2923,Fiscalizacion,1
#
# smontenegro2923,SerieA_Ec,3
#
# smontenegro2923,Unidosesmejor,1
#
# smontenegro2923,FeriaCiudadana,1
#
# smontenegro2923,Correa,8
#
# smontenegro2923,QueSeLevantan,1
#
# smontenegro2923,TRI,2
#
# smontenegro2923,DialogoNacional,9
#
# smontenegro2923,leyDeSolaridad,1
#
# smontenegro2923,EquidadISSFA,1
#
# smontenegro2923,TerremotoEcuador,1
#
# smontenegro2923,jovenes,1
#
# smontenegro2923,tricolor,1
#
# smontenegro2923,Marcha19M,1
#
# smontenegro2923,LeyDeTierras,2
#
# smontenegro2923,TecUni,1
#
# smontenegro2923,VamosTRI,2
#
# smontenegro2923,RiverEC,1
#
# smontenegro2923,manta,1
#
# smontenegro2923,SomosEcuador,2
#
# smontenegro2923,Machalilla,1
#
# smontenegro2923,Enlace429,1
#
# smontenegro2923,SomosMas,11
#
# smontenegro2923,YoVivoSinDrogasTuDecides,2
#
# smontenegro2923,ligadeportoviejo,1
#
# smontenegro2923,Tarqui,1
#
# smontenegro2923,RevolucionHospitalaria,1
#
# smontenegro2923,27S,4
#
# smontenegro2923,HabitatIII,2
#
# smontenegro2923,EU_Ecuador,1
#
# smontenegro2923,panama,1
#
# smontenegro2923,Portoviejo195anos,1
#
# smontenegro2923,Miduvi,1
#
# smontenegro2923,DaniloSuarez,2
#
# smontenegro2923,Calceta,7
#
# smontenegro2923,fuerza,1
#
# smontenegro2923,LeyDeRemision,2
#
# smontenegro2923,todoscontraelmicrotrafico,1
#
# smontenegro2923,HacemosFuturo,2
#
# smontenegro2923,Enlace433,4
#
# smontenegro2923,vamos,1
#
# smontenegro2923,RomeroVive,2
#
# smontenegro2923,FiscalizandoEnTerritorio,5
#
# smontenegro2923,JuntosPorLaRevolucion,1
#
# smontenegro2923,DEPORTES,1
#
# smontenegro2923,ComDerColectivos,16
#
# smontenegro2923,MIDUVI,7
#
# smontenegro2923,leydePlusvalia,1
#
# smontenegro2923,ApoyoLula,1
#
# smontenegro2923,AcuerdoUE,4
#
# smontenegro2923,Pajan,1
#
# smontenegro2923,garramanaba,2
#
# smontenegro2923,enmiendas,1
#
# smontenegro2923,RiverPlateEC,1
#
# smontenegro2923,RafaelParaElPueblo,33
#
# smontenegro2923,ViaColimesOlmedo,4
#
# smontenegro2923,DSC,1
#
# smontenegro2923,VisitaPapalEc,2
#
# smontenegro2923,vamosequipo,1
#
# smontenegro2923,EnmiendaConstitucional,6
#
# smontenegro2923,SanMateo,10
#
# smontenegro2923,LeyDeDrogas,1
#
# smontenegro2923,LaPatriaVa,1
#
# smontenegro2923,todosApoyar,1
#
# smontenegro2923,Rocafuerte,3
#
# smontenegro2923,capiradelalma,1
#
# smontenegro2923,GOD,1
#
# smontenegro2923,Periscope,2
#
# smontenegro2923,ComiteBinacional,1
#
# smontenegro2923,social,2
#
# smontenegro2923,SiEsConJorgeGlasEsConmigo,1
#
# smontenegro2923,Repost,1
#
# smontenegro2923,Bicentenario,1
#
# smontenegro2923,PatriaParaSiempre,1
#
# smontenegro2923,SomosRevolucion,12
#
# smontenegro2923,PorElDialogoTodo,1
#
# smontenegro2923,love,1
#
# smontenegro2923,Estadio7DeOctubre,1
#
# smontenegro2923,ldup,10
#
# smontenegro2923,VurgendeGuadalupePicoaza,1
#
# smontenegro2923,Juventudes,1
#
# smontenegro2923,TodosSomosRafael,2
#
# smontenegro2923,BinomioDelPueblo,2
#
# smontenegro2923,BarcelonaSC,1
#
# smontenegro2923,SantaAna,2
#
# smontenegro2923,AsambleaCoyunturaEconomica,2
#
# smontenegro2923,Ecuador,58
#
# smontenegro2923,FEDETAXI,1
#
# smontenegro2923,LaUvuelve,2
#
# smontenegro2923,PlazaGrande,3
#
# smontenegro2923,TecnicoUniversitario,3
#
# smontenegro2923,TodosConGlas,1
#
# smontenegro2923,LeydeHerencias,2
#
# smontenegro2923,Resumendeportivo,1
#
# smontenegro2923,FueraDerechaFuera,1
#
# smontenegro2923,FirstCommunion,1
#
# smontenegro2923,Ecua,1
#
# smontenegro2923,MovimientoPais,1
#
# smontenegro2923,ConCorazon,1
#
# smontenegro2923,JuntosSomosPais,3
#
# smontenegro2923,AbonadoLDUP,1
#
# smontenegro2923,trabajo,2
#
# smontenegro2923,BSC,3
#
# smontenegro2923,CumbreDeLasAmericas,1
#
# smontenegro2923,ESNUESTRA,1
#
# smontenegro2923,Brasil,1
#
# smontenegro2923,QUERIDA,1
#
# smontenegro2923,DialogoCiudadano,23
#
# smontenegro2923,viaSanAntonio,1
#
# smontenegro2923,atencion,1
#
# smontenegro2923,DeporteEsRevolucion,1
#
# smontenegro2923,SemanaSanta,1
#
# smontenegro2923,LaFrase,1
#
# smontenegro2923,Babahoyo,1
#
# smontenegro2923,Jipijapa,2
#
# smontenegro2923,MunicipalCanar,1
#
# smontenegro2923,Ecu911,1
#
# smontenegro2923,FutbolEC,3
#
# smontenegro2923,AvanzamosPatria,1
#
# smontenegro2923,SiembrantonEc,1
#
# smontenegro2923,ArribaU,3
#
# smontenegro2923,GOLMovistarEC,1
#
# smontenegro2923,ElFuturoNoSeDetiene,1
#
# smontenegro2923,Colombia,2
#
# smontenegro2923,Unidad,1
#
# smontenegro2923,LduP,1
#
# smontenegro2923,LigaEsDeSerieA,2
#
# smontenegro2923,TodosConLaU,1
#
# smontenegro2923,La,1
#
# smontenegro2923,conLDUPhastaelfinal,1
#
# smontenegro2923,siguemeytesigo,2
#
# smontenegro2923,Pichincha,1
#
# smontenegro2923,MTVStars,1
#
# smontenegro2923,Tera6,1
#
# smontenegro2923,SonoOnda,1
#
# smontenegro2923,Quiroga,3
#
# smontenegro2923,AsambleaNacional,2
#
# smontenegro2923,UnBuenDiaConSol,2
#
# smontenegro2923,VIDEO,2
#
# smontenegro2923,DeRaizManaba,2
#
# smontenegro2923,verdeyblanco,1
#
# smontenegro2923,SanPedroYSanPablo,2
#
# smontenegro2923,Justicia,1
#
# smontenegro2923,DineroElectronico,2
#
# smontenegro2923,FranciscoEnEcuador,2
#
# smontenegro2923,idolodemanabi,1
#
# smontenegro2923,MTVHottest,1
#
# smontenegro2923,EvoMorales,5
#
# smontenegro2923,guitarsolo,1
#
# smontenegro2923,RuedaDePrensa,3
#
# smontenegro2923,Herencias,1
#
# smontenegro2923,Transparencia,1
#
# smontenegro2923,musica,1
#
# smontenegro2923,LeyIncentivosTributarios,1
#
# smontenegro2923,DerechodeRepeticion,1
#
# smontenegro2923,Futsal,1
#
# smontenegro2923,JuntasParroquiales,3
#
# smontenegro2923,Fundacion,1
#
# smontenegro2923,TVmanabita,1
#
# smontenegro2923,CDMacara,1
#
# smontenegro2923,Latacunga,2
#
# smontenegro2923,equidad,3
#
# smontenegro2923,Policia,1
#
# smontenegro2923,NadieTocaMiRC,1
#
# smontenegro2923,revolucion,1
#
# smontenegro2923,FairPlay,1
#
# smontenegro2923,pais,1
#
# smontenegro2923,Jaramijo,3
#
# smontenegro2923,LosRios,1
#
# smontenegro2923,Futbol,2
#
# smontenegro2923,NuevoBancodePreguntasANT,1
#
# smontenegro2923,SerieB,28
#
# smontenegro2923,todosconRafael,1
#
# smontenegro2923,LeyIncentivosAPP,12
#
# smontenegro2923,FETUM,1
#
# smontenegro2923,FiscalizandoTerritorio,1
#
# smontenegro2923,Esmeraldas,6
#
# smontenegro2923,Debatefutbolxdirectv,1
#
# smontenegro2923,TodosUnidos,1
#
# smontenegro2923,deportivo,1
#
# smontenegro2923,nochecultural,1
#
# smontenegro2923,ConGarraManaba,1
#
# smontenegro2923,MafiaVerde,1
#
# smontenegro2923,LeyProteccionEmpleo,9
#
# smontenegro2923,Rusia2018,1
#
# smontenegro2923,CopaAmerica,1
#
# smontenegro2923,HabitatyVivienda,1
#
# smontenegro2923,chofer,1
#
# smontenegro2923,EnmiendaContitucional,1
#
# smontenegro2923,Viceprefecta,1
#
# smontenegro2923,FabianBustos,1
#
# smontenegro2923,Democracia,1
#
# smontenegro2923,EcuadorEnPositivo,1
#
# smontenegro2923,SegundoDebate,1
#
# smontenegro2923,ViviendaEc,1
#
# smontenegro2923,NuevaAgendaUrbana,1
#
# smontenegro2923,CrucitalaBella,1
#
# smontenegro2923,Transportistas,1
#
# smontenegro2923,Asambleista,1
#
# smontenegro2923,LosEsteros,1
#
# smontenegro2923,LeyPrevencionDroga,1
#
# smontenegro2923,ElPasadoNuncaMas,1
#
# smontenegro2923,24DeMayo,1
#
# smontenegro2923,LeySolidariaTerremoto,2
#
# smontenegro2923,Tamarindos,1
#
# smontenegro2923,ComisionDerechosColectivos,1
#
# smontenegro2923,ProhibidoOlvidar,3
#
# smontenegro2923,Guayas,5
#
# smontenegro2923,Bolivia,4
#
# smontenegro2923,MunCanar,1
#
# smontenegro2923,DerechoaLaReplica,1
#
# smontenegro2923,DebateEconomico,7
#
# smontenegro2923,Yaruqui,2
#
# smontenegro2923,EcuadorPaisDePaz,11
#
# smontenegro2923,MantaFC,10
#
# smontenegro2923,Reeleccion,1
#
# smontenegro2923,PortoviejoSeLevanta,1
#
# smontenegro2923,EliminatoriasRusia2018,3
#
# smontenegro2923,capira,3
#
# smontenegro2923,AguantelaU,2
#
# smontenegro2923,UnidosPorManabi,1
#
# smontenegro2923,RC,5
#
# smontenegro2923,IESS,1
#
# smontenegro2923,ciudadana,1
# smontenegro2923,Chone,6
#
# smontenegro2923,PlanReconstruYo,1
#
# smontenegro2923,EliminatoriasPorTC,1
#
# smontenegro2923,EducacionInterculturalBilingue,1
#
# smontenegro2923,todosUnidos,1
#
# smontenegro2923,FuerzaAmarilla,1
#
# smontenegro2923,TorneoEcuatoriano,1
#
# smontenegro2923,HRZ,1
#
# smontenegro2923,Miami,1
#
# smontenegro2923,ElPasadoNoVolvera,2
#
# smontenegro2923,transportistas,1
#
# smontenegro2923,EcuadorALevantarse,1
#
# smontenegro2923,Tecnico,2
#
# smontenegro2923,GarraManaba,6
#
# smontenegro2923,TriDeCorazon,2
#
# smontenegro2923,Jama,1
#
# smontenegro2923,LaTrataEsUnDelito,1
#
# smontenegro2923,Roma,1
#
# smontenegro2923,Enlace423,2
#
# smontenegro2923,DebateFutbolxDIRECTV,1
#
# smontenegro2923,EloyAlfaro,1
#
# smontenegro2923,ConfioEnTiEcuador,1
#
# smontenegro2923,futsala,2
#
# smontenegro2923,reales,1
#
# smontenegro2923,FenomenoDelNino,1
#
# smontenegro2923,direccionprovincial,1
#
# smontenegro2923,Enlace424,2
#
# smontenegro2923,VotarPorLaAsamblea,1
#
# smontenegro2923,Fiscalizando,1
#
# smontenegro2923,APP,1
#
# smontenegro2923,HabitatIII2016,2
#
# smontenegro2923,MercadodePases,1
#
# smontenegro2923,deportivocali,1
#
# smontenegro2923,Patria,2
#
# smontenegro2923,ANTMANABI,1
#
# smontenegro2923,TanGuayacoComo,1
#
# smontenegro2923,mandarina,1
#
# smontenegro2923,MangaDelCuraEsManabi,7
#
# smontenegro2923,PrimeroDeMayo,1
#
# smontenegro2923,EcuadorvsArgentina,1
#
# smontenegro2923,LidiceesManabi,1
#
# smontenegro2923,somosrevolucion,1
#
# smontenegro2923,laMangaEsManabita,1
#
# smontenegro2923,LeninPresidente,1
#
# smontenegro2923,PortoviejoNaceDeTi,3
#
# smontenegro2923,Sesion184,1
#
# smontenegro2923,13AdefenderLaRC,1
#
# smontenegro2923,GabrielaEnManabi,1
#
# smontenegro2923,LaDecadaGanada,4
#
# smontenegro2923,personasnaturales,1
#
# smontenegro2923,serieb_ec,4
#
# smontenegro2923,SanMarcos,1
#
# smontenegro2923,Peru,1
#
# smontenegro2923,Vaticano,1
#
# smontenegro2923,LeyDeHerencias,3
#
# smontenegro2923,EuroLat,1
#
# smontenegro2923,NoMasInfiltrados,1
#
# smontenegro2923,Reconstruir,1
#
# smontenegro2923,ColegioOlmedo,1
#
# smontenegro2923,Manta,19
#
# smontenegro2923,DireccionProvincial,3
#
# smontenegro2923,LigaAlaserieA,1
#
# smontenegro2923,Resultados24M,1
#
# smontenegro2923,1M,2
#
# smontenegro2923,PalestinaSolidario,1
#
# smontenegro2923,Reales,1
#
# smontenegro2923,GabineteProvincial,3
#
# smontenegro2923,Enlace420,1
#
# smontenegro2923,SUB16LDUP,3
#
# smontenegro2923,serieB,1
#
# smontenegro2923,AlPasadoNuncaMas,1
#
# smontenegro2923,serieA,1
#
# smontenegro2923,PuertoDeManta,2
#
# smontenegro2923,red,1
#
# smontenegro2923,ManabiSolidario,1
#
# smontenegro2923,Top10Ecuagol,1
#
# smontenegro2923,YoApoyoALaEnmienda,1
#
# smontenegro2923,Capira,11
#
# smontenegro2923,ProyectoRevolucionario,1
#
# smontenegro2923,VamosQueSePuede,1
#
# smontenegro2923,ManabiUnido,2
#
# smontenegro2923,AFE,2
#
# smontenegro2923,salvaguardias,2
#
# smontenegro2923,EcuadorPotenciaTuristica,1
#
# smontenegro2923,Charrito,1
#
# smontenegro2923,DaleCorreDale,1
#
# smontenegro2923,LaAsambleJuntoATi,1
#
# smontenegro2923,Oficial,1
#
# smontenegro2923,Cronica,1
#
# smontenegro2923,5ConvencionNacional,1
#
# smontenegro2923,SanVicente,3
#
# smontenegro2923,Macara,2
#
# smontenegro2923,Cnel,1
#
# smontenegro2923,redessociales,1
#
# smontenegro2923,RevolucionEducativa,1
#
# smontenegro2923,Portovejence,1
#
# smontenegro2923,RCSocial,1
#
# smontenegro2923,ClasicoManabita,1
#
# smontenegro2923,CambioClimatico,3
#
# smontenegro2923,portoviejo,1
#
# smontenegro2923,HeroesDeLaPatria,1
#
# smontenegro2923,Ec,1
#
# smontenegro2923,LDUPvsFuerzaAmarilla,1
#
# smontenegro2923,LeonardoOrlando,1
#
# smontenegro2923,FFAA,1
#
# smontenegro2923,YoSocioLDUP,2
#
# smontenegro2923,SRI,3
#
# smontenegro2923,MichelleBachelet,1
#
# smontenegro2923,TuiterosManabi,1
#
# smontenegro2923,Pastaza,1
#
# smontenegro2923,Siempre,1
#
# smontenegro2923,BonoDeArrendamiento,1
#
# smontenegro2923,DialogoConElPresidente,1
#
# smontenegro2923,RevolucionCuidadana,1
#
# smontenegro2923,ReconstruyoEcuador,1
#
# smontenegro2923,HugoVelez,1
#
# smontenegro2923,MushucRuna,2
#
# smontenegro2923,seleccion,1
#
# smontenegro2923,LeyDeComunicacion,5
#
# smontenegro2923,TurismoComunitario,4
#
# smontenegro2923,Obregon,1
#
# smontenegro2923,SocioVulcanizador,1
#
# smontenegro2923,multas,1
#
# smontenegro2923,MiseriaHunana,1
#
# smontenegro2923,SerieA,5
#
# smontenegro2923,ManabiAltivoYSoberano,1
#
# smontenegro2923,12h00,1
#
# smontenegro2923,Reasentamientos,1
#
# smontenegro2923,Delfin,1
#
# smontenegro2923,avanzamos,1
#
# smontenegro2923,todosjuntosporliga,1
#
# smontenegro2923,Archidona,3
#
# smontenegro2923,NoAlParo,1
#
# smontenegro2923,Seguismundo,1
#
# smontenegro2923,ViernesSanto,1
#
# smontenegro2923,ElDeporteNoPara,1
#
# smontenegro2923,UltimaHora,1
#
# smontenegro2923,ecuador,1
#
# smontenegro2923,HablandoLaPlenaComoElMashi,2
#
# smontenegro2923,justicia,2
#
# smontenegro2923,LaMangaDelCuraEsManabita,2
#
# smontenegro2923,MiPasionEsAmarilla,1
#
# smontenegro2923,TecnicoU,9
#
# smontenegro2923,PatriaUnida,1
#
# smontenegro2923,PrimeroLoNuestro,2
#
# smontenegro2923,Coord,1
#
# smontenegro2923,LDULvsLDUP,1
#
# smontenegro2923,CNEL,1
#
# smontenegro2923,PuertoPesqueroSanMateo,1
#
# smontenegro2923,ArturoJarrinmemoriasdeunalfarista,1
#
# smontenegro2923,Ricaurte,1
#
# smontenegro2923,ContigoDeLey,1
#
# smontenegro2923,MiFavorito32,1
#
# smontenegro2923,clasicomanabita,1
#
# smontenegro2923,MarcelinoMariduenaContigoRafael,1
#
# smontenegro2923,CopaManabi,5
#
# smontenegro2923,Quitumbe,1
#
# smontenegro2923,tecnico,2
#
# smontenegro2923,LeySolidaria,1
#
# smontenegro2923,CocinasDeInduccion,1
#
# smontenegro2923,RadioAmerica,1
#
# smontenegro2923,canar,1
#
# smontenegro2923,FiscalizacionDeObras,1
#
# smontenegro2923,GraciasRafael,1
#
# smontenegro2923,ElCiudadanoRadio,3
#
# smontenegro2923,Pais35,4
#
# smontenegro2923,Junto,1
#
# smontenegro2923,SiempreGrandeManabi,1
#
# smontenegro2923,MiduviZona4,1
#
# smontenegro2923,SeguridadCiudadana,1
#
# smontenegro2923,EcuadorCambio,1
#
# smontenegro2923,aucas,1
#
# smontenegro2923,ciudadano,5
#
# smontenegro2923,Tundayme,4
#
# smontenegro2923,Aucas,4
#
# smontenegro2923,rumboalaA,1
#
# smontenegro2923,CodigoInformativo,1
#
# smontenegro2923,Balao,1
#
# smontenegro2923,TO2015,7
#
# smontenegro2923,FirmaAcuerdoUE,1
#
# smontenegro2923,Comando_deportiva,1
#
# smontenegro2923,InformeALaNacion,1
#
# smontenegro2923,MangaDelCuraESManabi,1
#
# smontenegro2923,EcuadorSinMuerteMaterna,1
#
# smontenegro2923,StoDomingo,2
#
# smontenegro2923,Manabitas,1
#
# smontenegro2923,ligadePortoviejo,1
#
# smontenegro2923,mingaturismo,1
#
# smontenegro2923,Enmienda,5
#
# smontenegro2923,SomosDialogo,1
#
# smontenegro2923,LoHicimos,2
#
# smontenegro2923,trabajando,1
#
# smontenegro2923,9RC,1
#
# smontenegro2923,SiembratonEc,2
#
# smontenegro2923,canton,1
#
# smontenegro2923,OLMEDO,1
#
# smontenegro2923,LeyDeMovilidadHumana,1
#
# smontenegro2923,Elimiantorias,1
#
# smontenegro2923,SesionSolemne,3
#
# smontenegro2923,Guayaquil,7
#
# smontenegro2923,AlaSeriaA,1
#
# smontenegro2923,LaLeyeslaLey,2
#
# smontenegro2923,Enlace399,1
#
# smontenegro2923,LatinGRAMMY,1
#
# smontenegro2923,CeroSiniestrosDeTransito,1
#
# smontenegro2923,HumanistasConLenin,1
#
# smontenegro2923,LoDijoElPapa,1
#
# smontenegro2923,lamangadelcuraesmanabi,1
#
# smontenegro2923,35Pais,2
#
# smontenegro2923,SiguecorreaSigue,1
#
# smontenegro2923,Quinche,1
#
# smontenegro2923,VillaTeresa,1
#
# smontenegro2923,FiestaVerdeyBlanco,2
#
# smontenegro2923,RevolucionSocial,1
#
# smontenegro2923,CalcetaSeLevanta,2
#
# smontenegro2923,U,1
#
# smontenegro2923,LaGloriaEsDeCristo,1
#
# smontenegro2923,LeninYGlas,1
#
# smontenegro2923,unidad,2
#
# smontenegro2923,ligaportoviejo,1
#
# smontenegro2923,ConstruyendoElNuevoMomento,1
#
# smontenegro2923,Enlace432,8
#
# smontenegro2923,Carondelet,1
#
# smontenegro2923,FelizDiaDeLaMujer,1
#
# smontenegro2923,NoTeDejesEnganar,1
#
# smontenegro2923,futbol,1
#
# smontenegro2923,RiverPlate,2
#
# smontenegro2923,ciudadanos,1
#
# smontenegro2923,FiestaVerdeYBlanco,7
#
# smontenegro2923,Mcanar,1
#
# smontenegro2923,clasicoManaba,1
#
# smontenegro2923,LdUP,2
#
# smontenegro2923,DelfinSC,3
#
# smontenegro2923,Manabita,6
#
# smontenegro2923,LaMangadelCura,3
#
# smontenegro2923,Distrito2,2
#
# smontenegro2923,Trabajadores,1
#
# smontenegro2923,ConLaUHastaElFinal,1
#
# smontenegro2923,ANoDejarseEnganar,1
#
# smontenegro2923,NelsonMandela,1
#
# smontenegro2923,SERIEB,1
#
# smontenegro2923,turismo,1
#
# smontenegro2923,MiduviCumple,1
#
# smontenegro2923,ElParaisoLa14,2
#
# smontenegro2923,EcuadorYaCambio,18
#
# smontenegro2923,Palestina,1
#
# smontenegro2923,SantoD,1
#
# smontenegro2923,Ibarra,4
#
# smontenegro2923,igualdad,1
#
# smontenegro2923,ecuadorpaisdepaz,1
#
# smontenegro2923,Picoaza,1
#
# smontenegro2923,SomosMasManabi,1
#
# smontenegro2923,LigaMasculinaEC2014,1
#
# smontenegro2923,LigaAlaSerieA,1
#
# smontenegro2923,RIP,1
#
# smontenegro2923,VamosTricolor,1
#
# smontenegro2923,EEUU,1
#
# smontenegro2923,DefenderemosLoLogrado,4
#
# smontenegro2923,SerieB_Ec,38
#
# smontenegro2923,MemoriaAlfarista,2
#
# smontenegro2923,PuertosDignos,5
#
# smontenegro2923,YoDefiendoMiRevolucion,1
#
# smontenegro2923,NosLevantamos,1
#
# smontenegro2923,adictos,2
#
# smontenegro2923,Infomer1erTrimestre,1
#
# smontenegro2923,LigaNoSeVa,2
#
# smontenegro2923,MesdelManabitismo,1
#
# smontenegro2923,Espoli,12
#
# smontenegro2923,Serie_B,2
#
# smontenegro2923,dialogo,3
#
# smontenegro2923,SiSePuede,3
#
# smontenegro2923,BanosLimpios,1
#
# smontenegro2923,River,2
#
# smontenegro2923,SomosLaGarra,2
#
# smontenegro2923,Bahia,2
#
# smontenegro2923,LeydePlusvalia,2
#
# smontenegro2923,DropThatBass,1
#
# smontenegro2923,SUB18LDUP,1
#
# smontenegro2923,dalelaU,1
#
# smontenegro2923,LeyDeHe,1
#
# smontenegro2923,LibresDeDrogas,1
#
# smontenegro2923,LigaEsPasionDeUnPueblo,1
#
# smontenegro2923,LeydeComunas,1
#
# smontenegro2923,SantaElena,2
#
# smontenegro2923,TodosSomosManabi,1
#
# smontenegro2923,45AnosDePasion,3
#
# smontenegro2923,VivaManabi,1
#
# smontenegro2923,river,1
#
# smontenegro2923,MasDe1000Razones,1
#
# smontenegro2923,EnlaceCiudadano483,1
#
# smontenegro2923,2batallasLDUP,1
#
# smontenegro2923,DeportivoCali,1
#
# smontenegro2923,MasDeMilRazones,1
#
# smontenegro2923,voluntariadoLeonistico,1
#
# smontenegro2923,82Anos,1
#
# smontenegro2923,ENFOTOS,1
#
# smontenegro2923,LeyDeSolidaridad,3
#
# smontenegro2923,Sesion349,1
#
# smontenegro2923,LDUPvsTU,2
#
# smontenegro2923,FranciscoenEcuador,11
#
# smontenegro2923,AudienciaPublica,1
#
# smontenegro2923,artesanasyartesanosManta,1
#
# smontenegro2923,VamosSeleccion,1
#
# smontenegro2923,TUniversitario,3
#
# smontenegro2923,Hiya,1
#
# smontenegro2923,RevolucionDelTrabajo,8
#
# smontenegro2923,Argentina,11
#
# smontenegro2923,ConLaUhastaElFinal,1
#
# smontenegro2923,VamosManaba,1
#
# smontenegro2923,Enlace431,2
#
# smontenegro2923,BonoDeAyuda,1
#
# smontenegro2923,RafaelCorrea,2
#
# smontenegro2923,ImbaburaSC,2
#
# smontenegro2923,FelizCumpleanos,1
#
# smontenegro2923,ConsultaPopular,1
#
# smontenegro2923,sudamericano,2
#
# smontenegro2923,LAMEJORHINCHADADEMANABI,2
#
# smontenegro2923,Fortaleza,1
#
# smontenegro2923,SiEsConMartinEsConmigo,1
#
# smontenegro2923,Japon,1
#
# smontenegro2923,EvoEnManta,1
#
# smontenegro2923,RadioFarra,1
#
# smontenegro2923,Goluruguayo,1
#
# smontenegro2923,UnaSolaVuelta,1
#
# smontenegro2923,sub16,1
#
# smontenegro2923,semplades,1
#
# smontenegro2923,TodosALlenarElReales,1
#
# smontenegro2923,Eliminatorias,1
#
# smontenegro2923,LOEPS,1
#
# smontenegro2923,LaCapira,1
#
# smontenegro2923,Domingo,2
#
# smontenegro2923,URGENTE,2
#
# smontenegro2923,revolucionarias,1
#
# smontenegro2923,EcuadorNoPara,22
#
# smontenegro2923,RevolucionCiudadana,25
#
# smontenegro2923,infinitoamor,1
#
# smontenegro2923,SerieB_ec,5
#
# smontenegro2923,EconomiaPolularSolidaria,1
#
# smontenegro2923,PoliciaNacional,1
#
# smontenegro2923,AllYouNeedIsEcuador,1
#
# smontenegro2923,Friends,1
#
# smontenegro2923,PlayaLosPerales,1
#
# smontenegro2923,AndresMideros,1
#
# smontenegro2923,DiaDeLasMadres,1
#
# smontenegro2923,WeDeserveJustice,1
#
# smontenegro2923,Liga,2
#
# smontenegro2923,deportes,3
#
# smontenegro2923,ParqueSamanes,1
#
# smontenegro2923,ReconstruYoEcuador,9
#
# smontenegro2923,Aeropolicial,1
#
# smontenegro2923,yoSi,1
#
# smontenegro2923,Sesion174,2
#
# smontenegro2923,Tungurahua,2
#
# smontenegro2923,Enlace442,2
#
# smontenegro2923,ELSALVADOR,1
#
# smontenegro2923,Quevedo,4
#
# smontenegro2923,RadioModelo,1
#
# smontenegro2923,Priscilla,1
#
# smontenegro2923,papaFrancisco,1
#
# smontenegro2923,Patriaparasiempre,1
#
# smontenegro2923,LeyEquilibrioFinanzas,3
#
# smontenegro2923,ManabiExporta,1
#
# smontenegro2923,UFCxFOX,1
#
# smontenegro2923,HablandoDePolitica,1
#
# smontenegro2923,UnidosSomosInvencibles,1
#
# smontenegro2923,leyDeDrogas,1
#
# smontenegro2923,COA,1
#
# smontenegro2923,AgendaProductiva,4
#
# smontenegro2923,SiEsConRafaelEsConmigo,1
#
# smontenegro2923,Loja,1
#
# smontenegro2923,GARRAMANABA,1
#
# smontenegro2923,RafaelparaelPueblo,1
#
# smontenegro2923,FENACOTRAPE,1
#
# smontenegro2923,PapaFrancisco,10
#
# smontenegro2923,debateeconomico,1
#
# smontenegro2923,ANTSantaElena,1
#
# smontenegro2923,Zona4,1
#
# smontenegro2923,LaCapiraVuelve,2
#
# smontenegro2923,ManabiEsDeLaMangaDelCura,1
#
# smontenegro2923,JuegosDeLaRevolucion,2
#
# smontenegro2923,Mariano,2
#
# smontenegro2923,Guajalo,2
#
# smontenegro2923,LaMejorHinchadadeManabi,1
#
# smontenegro2923,16A,1
#
# smontenegro2923,ContigoSeleccion,1
#
# smontenegro2923,ambiente,1
#
# smontenegro2923,TVM,1
#
# smontenegro2923,CSLizarzaburu,3
#
# smontenegro2923,RT,2
#
# smontenegro2923,California,1
#
# smontenegro2923,SomosPaz,1
#
# smontenegro2923,CarlosVazquez,1
#
# smontenegro2923,RevolucionEnMarcha,1
#
# smontenegro2923,BordedeCampo,1
#
# smontenegro2923,LeyJusticiaLaboral,2
#
# smontenegro2923,lidicelarrea,1
#
# smontenegro2923,ArturoJarrin,3
#
# smontenegro2923,Cotopaxi,2
#
# smontenegro2923,LeyPrevencionDrogas,4
#
# smontenegro2923,TodasLasManosTodas,4
#
# smontenegro2923,futsal,1
#
# smontenegro2923,ContigoCambiamosEcuador,1
#
# smontenegro2923,EcuadorTieneHeroes,4
#
# smontenegro2923,SeguridadVial,1
#
# smontenegro2923,GabineteItinerante,1
#
# smontenegro2923,VivirSinDrogas,1
#
# smontenegro2923,VeladaLibertaria,2
#
# smontenegro2923,DAzogues,6
#
# smontenegro2923,DialogoPorEquidad,6
#
# smontenegro2923,FeriadoSeguro,1
#
# smontenegro2923,SELECCION,1
#
# smontenegro2923,Espam,1
#
# smontenegro2923,ECU911Conmigo,1
#
# smontenegro2923,DialogoPresidente,1
#
# smontenegro2923,2Batallas,1
#
# smontenegro2923,terrorismo,1
#
# smontenegro2923,AllenarlacasaLDUP,1
#
# smontenegro2923,BasurcoLDUP,1
#
# smontenegro2923,MangadelCura,6
#
# smontenegro2923,LeyAPP,2
#
# smontenegro2923,EducacionSuperior,1
#
# smontenegro2923,LaUesDePrimera,1
#
# smontenegro2923,5dJ,1
#
# smontenegro2923,Galapagos,5
#
# smontenegro2923,Siembratonec,1
#
# smontenegro2923,capirohastalashuevas,1
#
# smontenegro2923,enlace,2
#
# smontenegro2923,VamosConTodoCapira,1
#
# smontenegro2923,Contigo,1
#
# smontenegro2923,RumboAcuerdoUE,2
#
# smontenegro2923,19M,5
#
# smontenegro2923,oposicion,1
#
# smontenegro2923,ManabiMasUnido,1
#
# smontenegro2923,ElDeporteEsSalud,1
#
# smontenegro2923,DiadelPescadorArtesanal,1
#
# smontenegro2923,paz,1
#
# smontenegro2923,Gooooooool,1
#
# smontenegro2923,ENVIDEO,1
#
# smontenegro2923,leydeHerencia,1
#
# smontenegro2923,liga,1
#
# smontenegro2923,PrimeraB,1
#
# smontenegro2923,nuevomomentopais,1
#
# smontenegro2923,Viva2016,1
#
# smontenegro2923,ApoyoTotal,1
#
# smontenegro2923,reconstruccion,1
#
# smontenegro2923,PerDebate14,1
#
# smontenegro2923,EliminatoriasSudamericanas,1
#
# smontenegro2923,recargos,1
#
# smontenegro2923,todos,1
#
# smontenegro2923,MangaDelcura,1
#
# smontenegro2923,UTC,3
#
# smontenegro2923,Prepcom2,1
#
# smontenegro2923,zona4,1
#
# smontenegro2923,90MinutosPorManabi,2
#
# smontenegro2923,SemanaSantaenGuayas,1
#
# smontenegro2923,CharlieCharlieChallenge,1
#
# smontenegro2923,OscarRomero,1
#
# smontenegro2923,Barcelona,3
#
# smontenegro2923,camino,1
#
# smontenegro2923,VP,1
#
# smontenegro2923,ManabiUnidoySolidario,2
#
# smontenegro2923,SiembratonEC,3
#
# smontenegro2923,LaCalifornia,1
#
# smontenegro2923,GrupoDeHistericas,1
#
# smontenegro2923,IC,1
#
# smontenegro2923,WalterSolis,1
#
# smontenegro2923,VamosEcuador,1
#
# smontenegro2923,CambiaTuChip,4
#
# smontenegro2923,Concierto1x1,3
#
# smontenegro2923,ManabiSeReactiva,2
#
# smontenegro2923,Bogota,1
#
# smontenegro2923,ElNacional,2
#
# smontenegro2923,min,1
#
# smontenegro2923,NuevomomentoAP,1
#
# smontenegro2923,ManabiPotenciaAgraria,3
#
# smontenegro2923,contribuyentes,1
#
# smontenegro2923,MayPac,1
#
# smontenegro2923,sub20,1
#
# smontenegro2923,ARG,1
#
# smontenegro2923,Paraguay,1
#
# smontenegro2923,buenvivir,1
#
# smontenegro2923,GabrielaRivadeneira,1
#
# smontenegro2923,gatinha,1
#
# smontenegro2923,LosMismosDeSiempre,2
#
# smontenegro2923,trabajadores,1
#
# smontenegro2923,SerieBEc,2
#
# smontenegro2923,EconomiaPopularSolidaria,1
#
# smontenegro2923,BA,1
#
# smontenegro2923,tecnicou,1
#
# smontenegro2923,LDUPvsCDO,1
#
# smontenegro2923,IEPS,3
#
# smontenegro2923,EPS,2
#
# smontenegro2923,ConversatorioMedios,1
#
# smontenegro2923,DaleLaU,3
#
# smontenegro2923,patria,1
#
# smontenegro2923,BonoDeAcogida,2
#
# smontenegro2923,Gabinete100,1
#
# smontenegro2923,DebateSinMentirasOposicion,1
#
# smontenegro2923,Mies,2
#
# smontenegro2923,SiempreSolidario,1
#
# smontenegro2923,ReformaCOIP,1
#
# smontenegro2923,EcuadorConmigo,1
#
# smontenegro2923,Reeleccion2017,1
#
# smontenegro2923,GeneralSur,1
#
# smontenegro2923,EsVotarPorRafael,1
#
# smontenegro2923,1deMayo,1
#
# smontenegro2923,EleccionesBolivia,1
#
# smontenegro2923,AmasDeCasa,2
#
# smontenegro2923,Sub12LDUP,1
#
# smontenegro2923,SismoEcuador,1
#
# smontenegro2923,UCC36,1
#
# smontenegro2923,UEMCarlosRomoDavila,1
#
# smontenegro2923,Cootad,1
#
# smontenegro2923,NosRenovamos,1
#
# smontenegro2923,Tri,1
#
# smontenegro2923,LigaDePortoviejo,8
#
# smontenegro2923,DeporteEsSalud,1
#
# smontenegro2923,LDUP,327
#
# smontenegro2923,DialogoporEquidadMontecristi,1
#
# smontenegro2923,ParqueBicentenario,1
#
# smontenegro2923,fuerzacapirita,1
#
# smontenegro2923,Manduriacu,4
#
# smontenegro2923,Sistema,1
#
# smontenegro2923,Enlace421,1
#
# smontenegro2923,MAGAP,1
#
# smontenegro2923,BoliviaDecide,1
#
# smontenegro2923,Olmedo,9
#
# smontenegro2923,GabineteArchidona,1
#
# smontenegro2923,LeyDeJusticiaLaboral,1
#
# smontenegro2923,Comunidadeducativaenlinea,1
#
# smontenegro2923,FuerzaEcuador,1
#
# smontenegro2923,Felizmiercoles,1
#
# smontenegro2923,San,1
#
# smontenegro2923,LigadePortoviejo,5
#
# smontenegro2923,CumbrePanama,2
#
# smontenegro2923,SeguridadSocial,1
#
# smontenegro2923,DecenioAfrodescendiente,1
#
# smontenegro2923,Prefecto,2
#
# smontenegro2923,EstadioRealesTamarindos,3
#
# smontenegro2923,ColiseoLaCalifornia,1
#
# smontenegro2923,DiaDelChoferEcuatoriano,1
#
# smontenegro2923,SdAucas,1
#
# smontenegro2923,PaisManabiSusanaLidice,1
#
# smontenegro2923,VamosaVolverMiCapira,1
#
# smontenegro2923,FelizCumplePresi,1
#
# smontenegro2923,Charapoto,1
#
# smontenegro2923,CorazonesArdientes,1
#
# smontenegro2923,AsambleistasDeManabi,1
#
# smontenegro2923,Crucita,2
#
# smontenegro2923,Arg,1
#
# smontenegro2923,EcuadorEsTuCancha,1
#
# smontenegro2923,ElVaticano,3
#
# smontenegro2923,ManabiUnidoSolidario,1
#
# smontenegro2923,CampeonatoEcuatoriano,5
#
# smontenegro2923,EvoMasVivoQueNunca,1
#
# smontenegro2923,ESPOLI,2
#
# smontenegro2923,CiudadJardin,1
#
# smontenegro2923,Ldup,4
#
# smontenegro2923,SudamericanoSub17,3
#
# smontenegro2923,LaTricolor,1
#
# smontenegro2923,PorFinMiCasa,3
#
# smontenegro2923,Enlace411,7
#
# smontenegro2923,VerguenzaEnLoja,1
#
# smontenegro2923,ManabiSeLevanta,14
#
# smontenegro2923,Asambleistasmanabitas,1
#
# smontenegro2923,LigaRumboALaSerieA,1
#
# smontenegro2923,GraciasPorTanto,1
#
# smontenegro2923,IdoloDeManabi,2
#
# smontenegro2923,ParaisoLa14,1
#
# smontenegro2923,AcuerdoLegislativo,1
#
# smontenegro2923,FutbolxDIRECTV,2
#
# smontenegro2923,PAIS,2
#
# smontenegro2923,OficinaDePuertasAbiertas,1
#
# smontenegro2923,La_U_Vuelve,1
#
# smontenegro2923,Automotores,1
#
# smontenegro2923,manabita,2
#
# smontenegro2923,TodoManabiUnido,1
#
# smontenegro2923,Quito,23
#
# smontenegro2923,Cuba,2
#
# smontenegro2923,LeydeSolidaridad,1
#
# smontenegro2923,Salvaguardias,5
#
# smontenegro2923,30S,1
#
# smontenegro2923,garraManaba,1
#
# smontenegro2923,Gobierno,1
#
# smontenegro2923,Duenas,1
#
# smontenegro2923,ManabiPresente,2
#
# smontenegro2923,prohibidolvidar,1
#
# smontenegro2923,Campeonato,1
#
# smontenegro2923,serieB_ec,2
#
# smontenegro2923,LDUPmiPasion,1
#
# smontenegro2923,EnmiendasConstitucionales,5
#
# smontenegro2923,Conozca,1
#
# smontenegro2923,TodosSomosEcuador,1
#
# smontenegro2923,CondecoracionAsamblea,1
#
# smontenegro2923,OposicionTrucha,1
#
# smontenegro2923,LigaPasionDeUnPueblo,1
#
# smontenegro2923,ECUADORHISTORICO,1
#
# smontenegro2923,Hnos,1
#
# smontenegro2923,ULTIMOMINUTO,1
#
# smontenegro2923,TodoToditito35,1
#
# smontenegro2923,SiguenAdelante,1
#
# smontenegro2923,santo,2
#
# smontenegro2923,BAHIA,1
#
# smontenegro2923,PorLaEquidadyLaJusticiaSocial,2
#
# smontenegro2923,ParticipacionCiudadana,1
#
# smontenegro2923,ElGobiernoCumple,1
#
# smontenegro2923,LeySolidariaReconstruccion,2
#
# smontenegro2923,PuertoLopez,11
#
# smontenegro2923,Conagopare,1
#
# smontenegro2923,NuevoMomentoPais,1
#
# smontenegro2923,HoracioSalaberry,1
#
# smontenegro2923,EcuadorListoYSolidario,4
#
# smontenegro2923,CocaCity,1
#
# smontenegro2923,GiroxESPN,1
#
# smontenegro2923,ViceCampeonCopaLibetadores,1
#
# smontenegro2923,JoseAGarciaV,1
#
# smontenegro2923,MasUnidosQueNunca,1
#
# smontenegro2923,SabadoDeGanarSeguidores,1
#
# smontenegro2923,fortaleza,1
#
# smontenegro2923,cinturondeseguridad,1
#
# smontenegro2923,AnosViejos,1
#
# smontenegro2923,ManabiEresTu,1
#
# smontenegro2923,Productiva,1
#
# smontenegro2923,Sub16LDUP,5
#
# smontenegro2923,EcuadorTeAbraza,2
#
# smontenegro2923,AgendaLegislativa,1
#
# smontenegro2923,asambleistas,1
#
# smontenegro2923,DiaMundialdelAgua,1
#
# smontenegro2923,Portoviejo195Anos,1
#
# smontenegro2923,FiestasdeGuayaquil,1
#
# smontenegro2923,CanoaSeLevanta,2
#
# smontenegro2923,UnidosTodosPorLiga,1
#
# smontenegro2923,ElGolDelAnoLDUP,1
#
# smontenegro2923,ElMomentoEsAhora,1
#
# smontenegro2923,Plop,1
#
# smontenegro2923,MangaDelCura,8
#
# smontenegro2923,Gobernadores,1
#
# smontenegro2923,TriunfoHistorico,1
#
# smontenegro2923,MasFirmesQueNunca,3
#
# smontenegro2923,DerechosLinguisticos,2
#
# smontenegro2923,CulturaVial,2
#
# smontenegro2923,Urdaneta,2
#
# smontenegro2923,ALaPremierConDIRECTV,1
#
# smontenegro2923,EnmiendasPorEcuador,1
#
# smontenegro2923,Riobamba,5
#
# smontenegro2923,HR,1
#
# smontenegro2923,ManabiEsPais,1
#
# smontenegro2923,Chile,2
#
# smontenegro2923,VamosCapira,5
#
# smontenegro2923,TeAcuerdasYTeDuele,1
#
# smontenegro2923,Azogues,1
#
# smontenegro2923,LeyEducacionIntercultural,1
#
# smontenegro2923,happy,1
#
# smontenegro2923,FEF,5
#
# smontenegro2923,EntrevistaGiron,1
#
# smontenegro2923,JuntoAEl,1
#
# smontenegro2923,CUT,2
#
# smontenegro2923,NoALasDrogas,1
#
# smontenegro2923,ClubDeCuervos,1
#
# smontenegro2923,Portoviejo,46
#
# smontenegro2923,batalla,1
#
# smontenegro2923,CnelManabi,2
#
# ...
#
# qhacer_manabi,canon_photos_daily,1
#
# qhacer_manabi,Jam,1
#
# qhacer_manabi,Mantahost,1
#
# qhacer_manabi,waterfalls,1
#
# qhacer_manabi,travelbug,1
#
# qhacer_manabi,tierrahermosademissuenos,2
#
# qhacer_manabi,Heroe593,1
#
# qhacer_manabi,view,2
#
# qhacer_manabi,ceibos,2
#
# qhacer_manabi,lavidfotografia,1
#
# qhacer_manabi,CasaSurf,1
#
# qhacer_manabi,QueHace,2
#
# qhacer_manabi,LaMansionEmbrujada,12
#
# qhacer_manabi,cerroguayas,1
#
# qhacer_manabi,Pi,1
#
# qhacer_manabi,Po,3
#
# qhacer_manabi,underarmour,1
#
# qhacer_manabi,luz,1
#
# qhacer_manabi,nature,39
#
# qhacer_manabi,tend,1
#
# qhacer_manabi,icecream,1
#
# qhacer_manabi,montubio,1
#
# qhacer_manabi,ricacomidamanaba,1
#
# qhacer_manabi,deepforest,1
#
# qhacer_manabi,sobrinos,1
#
# qhacer_manabi,sanloco,1
#
# qhacer_manabi,PuertoCayo,13
#
# qhacer_manabi,mantaselevanta,2
#
# qhacer_manabi,tripadvisor,2
#
# qhacer_manabi,EstoEsEcuador,1
#
# qhacer_manabi,MakeUp,2
#
# qhacer_manabi,seque,1
#
# qhacer_manabi,panamahat,1
#
# qhacer_manabi,PuebloNuevo,5
#
# qhacer_manabi,cruzita,1
#
# qhacer_manabi,PortoviejoCity,1
#
# qhacer_manabi,grocella,1
#
# qhacer_manabi,DiaMundialDeLaLuchaContraElCancer,1
#
# qhacer_manabi,renault,1
#
# qhacer_manabi,beautifuldestinations,1
#
# qhacer_manabi,Sand,1
#
# qhacer_manabi,trova,1
#
# qhacer_manabi,beautifulplace,1
#
# qhacer_manabi,bellaca,1
#
# qhacer_manabi,instameetEc,15
#
# qhacer_manabi,inicioDeAno,1
#
# qhacer_manabi,co,2
#
# qhacer_manabi,bahiabeachconstruction,1
#
# qhacer_manabi,NocheTrasNoche,1
#
# qhacer_manabi,TucoYSarita,1
#
# qhacer_manabi,genre,1
#
# qhacer_manabi,cafePasado,1
#
# qhacer_manabi,raulcabrera,1
#
# qhacer_manabi,RutaManab,3
#
# qhacer_manabi,respect,1
#
# qhacer_manabi,Nominadas,1
#
# qhacer_manabi,Relax,1
#
# qhacer_manabi,ReinaDePortoviejo,1
#
# qhacer_manabi,unplacerquetemereces,1
#
# qhacer_manabi,Dirt,1
#
# qhacer_manabi,cena,6
#
# qhacer_manabi,mywork,1
#
# qhacer_manabi,Cocinamos,1
#
# qhacer_manabi,UnidosParaServir,1
#
# qhacer_manabi,discoteca,1
#
# qhacer_manabi,latinosa,1
#
# qhacer_manabi,sabores,1
#
# qhacer_manabi,amo_mi_vida,1
#
# qhacer_manabi,instagood,16
#
# qhacer_manabi,DocManabi,3
#
# qhacer_manabi,stunning,1
#
# qhacer_manabi,puertocayobeach,1
#
# qhacer_manabi,RutaManabi,404
#
# qhacer_manabi,bluefeet,1
#
# qhacer_manabi,va,1
#
# qhacer_manabi,ecuadorfotografia,1
#
# qhacer_manabi,Mugs,5
#
# qhacer_manabi,marthaloor,1
#
# qhacer_manabi,lush,1
#
# qhacer_manabi,lastunas,2
#
# qhacer_manabi,bucke,1
#
# qhacer_manabi,pesca,2
#
# qhacer_manabi,Beach,6
#
# qhacer_manabi,ElMejorFeriadoEC,4
#
# qhacer_manabi,RumboalaCorona,1
#
# qhacer_manabi,hamaca,2
#
# qhacer_manabi,ViajerosEnCamino,1
#
# qhacer_manabi,MyDinner,1
#
# qhacer_manabi,gastr,1
#
# qhacer_manabi,urdhvadha,1
#
# qhacer_manabi,QueHacerEnM,1
#
# qhacer_manabi,ArtistaFemeninaDelAnoVideocontrol,1
#
# qhacer_manabi,pho,1
#
# qhacer_manabi,promo,1
#
# qhacer_manabi,Carnaval,5
#
# qhacer_manabi,RutaMan,7
#
# qhacer_manabi,praia,1
#
# qhacer_manabi,cinematographer,1
#
# qhacer_manabi,instatravel,3
#
# qhacer_manabi,Espectacular,1
#
# qhacer_manabi,skylovers,2
#
# qhacer_manabi,platano,1
#
# qhacer_manabi,recordando,1
#
# qhacer_manabi,i,3
#
# qhacer_manabi,dulcetentacionporto,8
#
# qhacer_manabi,EscapateConmigo,1
#
# qhacer_manabi,MantaEspect,1
#
# qhacer_manabi,yoamoamanabi,19
#
# qhacer_manabi,raulnomada,1
#
# qhacer_manabi,LuisEnrique,1
#
# qhacer_manabi,moments,2
#
# qhacer_manabi,loveit,1
#
# qhacer_manabi,carajo,1
#
# qhacer_manabi,momento,1
#
# qhacer_manabi,Influencer,9
#
# qhacer_manabi,happiness,1
#
# qhacer_manabi,RobotLed,1
#
# qhacer_manabi,vida,2
#
# qhacer_manabi,Friday,1
#
# qhacer_manabi,sky,15
#
# qhacer_manabi,Verde,1
#
# qhacer_manabi,muelle,1
#
# qhacer_manabi,apartamentos,1
#
# qhacer_manabi,RoyalTourEcua,1
#
# qhacer_manabi,FlavioAlfaro,1
#
# qhacer_manabi,palmtrees,1
#
# qhacer_manabi,T,1
#
# qhacer_manabi,facial,1
#
# qhacer_manabi,PARTY,4
#
# qhacer_manabi,pinceldecristo,1
#
# qhacer_manabi,Influence,2
#
# qhacer_manabi,clown,1
#
# qhacer_manabi,allyou,1
#
# qhacer_manabi,musicaenvivo,1
#
# qhacer_manabi,paragliding,2
#
# qhacer_manabi,beachlover,3
#
# qhacer_manabi,MundoPlus,1
#
# qhacer_manabi,HippieChic,1
#
# qhacer_manabi,Sun,2
#
# qhacer_manabi,AllYouNee,1
#
# qhacer_manabi,hair,3
#
# qhacer_manabi,victoriasecret,1
#
# qhacer_manabi,home,1
#
# qhacer_manabi,manabita,1
#
# qhacer_manabi,Cocteles,1
#
# qhacer_manabi,campfire,1
#
# qhacer_manabi,sanvalentin,1
#
# qhacer_manabi,beachli,1
#
# qhacer_manabi,LaN,1
#
# qhacer_manabi,manta,24
#
# qhacer_manabi,ManabaNoPares,1
#
# qhacer_manabi,Beautifuldestinations,1
#
# qhacer_manabi,cursosbuc,1
#
# qhacer_manabi,rockcity,6
#
# qhacer_manabi,pilsener,1
#
# qhacer_manabi,stage,1
#
# qhacer_manabi,campito,1
#
# qhacer_manabi,goodmoment,1
#
# qhacer_manabi,AlegraEc,1
#
# qhacer_manabi,southamerica,4
#
# qhacer_manabi,latepost,2
#
# qhacer_manabi,cabalon,1
#
# qhacer_manabi,rodeo,1
#
# qhacer_manabi,gratomomento,1
#
# qhacer_manabi,ecuadortravel,4
#
# qhacer_manabi,DiaDeLosHumedales,1
#
# qhacer_manabi,pistols,1
#
# qhacer_manabi,gastronomy,2
#
# qhacer_manabi,MantequilladeMani,1
#
# qhacer_manabi,nofilterneeded,2
#
# qhacer_manabi,DescubrePedernales,3
#
# qhacer_manabi,Josedu287,1
#
# qhacer_manabi,FELIZ,1
#
# qhacer_manabi,BonanzaBeer,1
#
# qhacer_manabi,artesanos,1
#
# qhacer_manabi,Super37,1
#
# qhacer_manabi,SonyXp,1
#
# qhacer_manabi,myfavoriteplace,1
#
# qhacer_manabi,followme,2
#
# qhacer_manabi,Bailame,1
#
# qhacer_manabi,Talent,1
#
# qhacer_manabi,Asuntate,2
#
# qhacer_manabi,allyouneedisecuador593,1
#
# qhacer_manabi,Ceiba,1
#
# qhacer_manabi,amorgatuno,1
#
# qhacer_manabi,entrelosuburbano,10
#
# qhacer_manabi,arboles,1
#
# qhacer_manabi,ParapentePu,1
#
# qhacer_manabi,guitarra,1
#
# qhacer_manabi,ha,1
#
# qhacer_manabi,Publicidad,1
#
# qhacer_manabi,pi,1
#
# qhacer_manabi,places,1
#
# qhacer_manabi,manabiprimero,1
#
# qhacer_manabi,ecuadorisallyouneed,1
#
# qhacer_manabi,Maxyyo,1
#
# qhacer_manabi,RoyalTourEcuad,1
#
# qhacer_manabi,cake,1
#
# qhacer_manabi,Arte,3
#
# qhacer_manabi,islasalango,2
#
# qhacer_manabi,tallships,1
#
# qhacer_manabi,pic,3
#
# qhacer_manabi,soloenlacaverna,1
#
# qhacer_manabi,ins,1
#
# qhacer_manabi,mejor,1
#
# qhacer_manabi,asfalto,1
#
# qhacer_manabi,photostreet,1
#
# qhacer_manabi,portolove,1
#
# qhacer_manabi,Piloso,1
#
# qhacer_manabi,Demolicion,1
#
# qhacer_manabi,pulseras,2
#
# qhacer_manabi,spraypaint,1
#
# qhacer_manabi,finca,1
#
# qhacer_manabi,chocolab,1
#
# qhacer_manabi,adrianabarka,1
#
# qhacer_manabi,scubadiving,1
#
# qhacer_manabi,Recuerdo,1
#
# qhacer_manabi,yogabeach,1
#
# qhacer_manabi,violenciaintrafamiliar,3
#
# qhacer_manabi,backstage,1
#
# qhacer_manabi,visitanos,1
#
# qhacer_manabi,Resta,2
#
# qhacer_manabi,vsco,1
#
# qhacer_manabi,Rio2016,1
#
# qhacer_manabi,greenplanet,1
#
# qhacer_manabi,goprohero4,3
#
# qhacer_manabi,paisajesecuador,4
#
# qhacer_manabi,salprieta,3
#
# qhacer_manabi,livemylife,1
#
# qhacer_manabi,theparadise,1
#
# qhacer_manabi,blackwhite,2
#
# DiarioelManaba,SaborGuayaco,1
#
# radioscandalo,DelfinSC,25
#
# radioscandalo,StoDomingo,1
#
# radioscandalo,Ginzaremix,1
#
# radioscandalo,Elecciones2014,3
#
# radioscandalo,BocaJuniors,1
#
# radioscandalo,hacetiempo,1
#
# radioscandalo,Seguimos,2
#
# radioscandalo,EscuelasDeFamilia,1
#
# radioscandalo,MantaFc,3
#
# radioscandalo,Bolivar,1
#
# radioscandalo,VEN,5
#
# radioscandalo,RuedadePrensa,2
#
# radioscandalo,SerieB_EC,8
#
# radioscandalo,IkerCasillas,1
#
# radioscandalo,FUTSAL,1
#
# radioscandalo,Guayas,1
#
# radioscandalo,UnidadCambioYProgreso,1
#
# radioscandalo,Argentina,10
#
# radioscandalo,Bolivia,2
#
# radioscandalo,Palestina,1
#
# radioscandalo,RADIOSCANDALO,1
#
# radioscandalo,SuperficialHaAshEcuador,1
#
# radioscandalo,DonaldTrump,1
#
# radioscandalo,DelfInSC,1
#
# radioscandalo,Liverpool,1
#
# radioscandalo,RIVER,3
#
# radioscandalo,MillonesDeGallosRojos,1
#
# radioscandalo,AntonioValencia,2
#
# radioscandalo,Posiciones,1
#
# radioscandalo,Fecha35,1
#
# radioscandalo,9DeOctubre,1
#
# radioscandalo,MantaFC,12
#
# radioscandalo,Rocafuerte,2
#
# radioscandalo,Fecha33,1
#
# radioscandalo,EEUU,3
#
# radioscandalo,FiestasPortoviejo,1
#
# radioscandalo,DiegoAlarcon,1
#
# radioscandalo,45anosdePasion,1
#
# radioscandalo,SerieB_Ec,20
#
# radioscandalo,AValencia,1
#
# radioscandalo,AlInfinito,1
#
# radioscandalo,Manabi,53
#
# radioscandalo,SERIEB_EC,1
#
# radioscandalo,SeAcabo,2
#
# radioscandalo,DAzogues,10
#
# radioscandalo,24deMayo,2
#
# radioscandalo,EuropaLeague,2
#
# radioscandalo,AscensoEcuador,15
#
# radioscandalo,surflimon,1
#
# radioscandalo,GPM,1
#
# radioscandalo,ldup,1
#
# radioscandalo,Legislativos,1
#
# radioscandalo,Paraguay,13
#
# radioscandalo,seguridad,1
#
# radioscandalo,AlajitaIbarra,1
#
# radioscandalo,PortoviejoEsManabi,1
#
# radioscandalo,Macara,9
#
# radioscandalo,Serie_B,1
#
# radioscandalo,Tecnico,1
#
# radioscandalo,SumandoEsfuerzos,1
#
# radioscandalo,CopaAmerica,66
#
# radioscandalo,RefuerzoVerdeyBlanco,1
#
# radioscandalo,ColonFc,10
#
# radioscandalo,ECUADOR,6
#
# radioscandalo,Enlace400,1
#
# radioscandalo,GoberManabi,2
#
# radioscandalo,LigadePortoviejo,1
#
# radioscandalo,Fecha29,3
#
# radioscandalo,MesDelManabitismo,1
#
# radioscandalo,nomeesperenEncasa,1
#
# radioscandalo,ScandaloDeportivo,2
#
# radioscandalo,Premier,1
#
# radioscandalo,Fecha26,1
#
# radioscandalo,Fecha27,1
#
# radioscandalo,DCuenca,7
#
# radioscandalo,TodosSomosManabi,2
#
# radioscandalo,RiverEcuador,1
#
# radioscandalo,ANTMANABI,1
#
# radioscandalo,DileAEl,1
#
# radioscandalo,Calderon,1
#
# radioscandalo,OmarPonce,1
#
# radioscandalo,Junin,1
#
# radioscandalo,MangaDelCuraEsManabi,2
#
# radioscandalo,ColonFC,7
#
# radioscandalo,Feat,1
#
# radioscandalo,radioscandalo,1
#
# radioscandalo,VideoClip,1
#
# radioscandalo,Guarani,1
#
# radioscandalo,VenezuelaDecide,2
#
# radioscandalo,Ldup,1
#
# radioscandalo,NocheDeEspectros,1
#
# radioscandalo,12h00,1
#
# radioscandalo,DELFIN,1
#
# radioscandalo,CIBV,2
#
# radioscandalo,UltimaHora,1
#
# radioscandalo,GuillermoAlmada,1
#
# radioscandalo,NocheVerdeyBlanco,1
#
# radioscandalo,PoloWila,1
#
# radioscandalo,GabrielaEnManabi,1
#
# radioscandalo,Pedernales,2
#
# radioscandalo,Joha,1
#
# radioscandalo,FeriadoSeguro,14
#
# radioscandalo,Peru,7
#
# radioscandalo,SomosScandalo,1
#
# radioscandalo,Imbabura,5
#
# radioscandalo,Manabitas,1
#
# radioscandalo,Machalilla,1
#
# radioscandalo,Chile2015,1
#
# radioscandalo,Espanyol,10
#
# radioscandalo,Brasi,1
#
# radioscandalo,LaMansion,1
#
# radioscandalo,LaAsambleaQueSonamos,1
#
# radioscandalo,Swansea,5
#
# radioscandalo,Bogota,1
#
# radioscandalo,PremierLeague,6
#
# radioscandalo,caramelo,1
#
# radioscandalo,PuertoLopez,1
#
# radioscandalo,LaNinaDeMisOjos,1
#
# radioscandalo,Atencion,2
#
# radioscandalo,Crucita,2
#
# radioscandalo,HamiltonPereira,1
#
# radioscandalo,Calceta,1
#
# radioscandalo,CdlasDelNorte,14
#
# radioscandalo,ECU911Conmigo,3
#
# radioscandalo,Bombero,1
#
# radioscandalo,Eleccciones2014,7
#
# radioscandalo,GrupoC,1
#
# radioscandalo,HablaManabi,1
#
# radioscandalo,GrupoA,1
#
# radioscandalo,11Cetaceo,1
#
# radioscandalo,DeportivoAzogues,1
#
# radioscandalo,RadioScandalo,32
#
# radioscandalo,EcEx,1
#
# radioscandalo,PrefectoMariano,1
#
# radioscandalo,MangaDelCura,3
#
# radioscandalo,2015Seguro,1
#
# radioscandalo,orgullo,2
#
# radioscandalo,SISMO,2
#
# radioscandalo,MALUMA,1
#
# radioscandalo,hospitalportoviejo,1
#
# radioscandalo,fecha37,1
#
# radioscandalo,ATENCION,1
#
# radioscandalo,DQuevedo,9
#
# radioscandalo,ElFuegoNoEsFuego,1
#
# radioscandalo,Pajan,1
#
# radioscandalo,ligasesalva,1
#
# radioscandalo,Fecha3,1
#
# radioscandalo,Uruguay,11
#
# radioscandalo,FLASHINFORMATIVO,1
#
# radioscandalo,LoNuevo,1
#
# radioscandalo,RiverPlate,1
#
# radioscandalo,CopaCentenario,1
#
# radioscandalo,LoInsolito,2
#
# radioscandalo,PeruVsEcuador,1
#
# radioscandalo,PacificoZambrano,1
#
# radioscandalo,Emelec,9
#
# radioscandalo,ClasicoManabita,3
#
# radioscandalo,ScandaloConLaTRI,2
#
# radioscandalo,RMadrid,9
#
# radioscandalo,portoviejo,1
#
# radioscandalo,cuidado,1
#
# radioscandalo,FUTBOL,1
#
# radioscandalo,CarlosRearte,1
#
# radioscandalo,eliminatoriasrusia2018,1
#
# radioscandalo,NuevaDirectiva,1
#
# radioscandalo,Watford,6
#
# radioscandalo,Cruzeiro,1
#
# radioscandalo,RadioScandaloConHaAsh,1
#
# radioscandalo,Enlace446,1
#
# radioscandalo,Galacticos,1
#
# radioscandalo,Ambato,1
#
# radioscandalo,UEMCastro,1
#
# radioscandalo,SantaFe,4
#
# radioscandalo,Chone,4
#
# radioscandalo,Fecha36,1
#
# radioscandalo,Temblor,1
#
# radioscandalo,ManabiEresTu,2
#
# radioscandalo,MEXICO,1
#
# radioscandalo,ObservadoresInternacionales,1
#
# radioscandalo,LDUQ,15
#
# radioscandalo,LDUP,43
#
# radioscandalo,Ministra,1
#
# radioscandalo,PARAGUAY,3
#
# radioscandalo,BahiaDeCaraquez,1
#
# radioscandalo,EcuadorYaCambio,1
#
# radioscandalo,Suplentes,1
#
# radioscandalo,ReinaDePortoviejo2015,1
#
# radioscandalo,LDUL,1
#
# radioscandalo,ChampiosLeague,1
#
# radioscandalo,BarcelonaSC,4
#
# radioscandalo,Hechos15Nov1922,1
#
# radioscandalo,Noticias,1
#
# radioscandalo,Ecuador,35
#
# radioscandalo,MiPersonaFavorita,1
#
# radioscandalo,Espoli,13
#
# radioscandalo,ManchesterCity,1
#
# radioscandalo,DanielAngulo,1
#
# radioscandalo,JeffMontero,2
#
# radioscandalo,rocafuerte,1
#
# radioscandalo,Delfin,1
#
# radioscandalo,PortoviejoFearCity,1
#
# radioscandalo,Salud,2
#
# radioscandalo,resultadosExtraoficiales,1
#
# radioscandalo,primerotepienso,1
#
# radioscandalo,RioVerde,1
#
# radioscandalo,11VerdeYBlanco,1
#
# radioscandalo,noteolvidoManabi,1
#
# radioscandalo,Enlace454,1
#
# radioscandalo,Lunallena,2
#
# radioscandalo,SegundaCategoria,3
#
# radioscandalo,ECU911Contigo,2
#
# radioscandalo,LaEsperanza,1
#
# radioscandalo,ByronCano,1
#
# radioscandalo,LaVidaEsFelicidad,1
#
# radioscandalo,Banguera,1
#
# radioscandalo,NuevoDT,1
#
# radioscandalo,Brasil,22
#
# radioscandalo,ADPM,1
#
# radioscandalo,CopaAmericaFutsal,1
#
# radioscandalo,NuevoDecano,1
#
# radioscandalo,Portoviejo,18
#
# radioscandalo,ConteoRapido,1
#
# radioscandalo,ClasicoDelAstillero,3
#
# radioscandalo,Dreer,1
#
# radioscandalo,RefuerzoCetaceo,2
#
# radioscandalo,GeneracionVerde,1
#
# radioscandalo,RefuerzoAlbiceleste,1
#
# radioscandalo,Chile,21
#
# radioscandalo,Datos,4
#
# radioscandalo,DepOtavalo,12
#
# radioscandalo,chile,1
#
# radioscandalo,MantFC,1
#
# radioscandalo,Jipijapa,2
#
# radioscandalo,futsal,2
#
# radioscandalo,Ecu911,6
#
# radioscandalo,Orgullo,1
#
# radioscandalo,Lachina,1
#
# radioscandalo,Liga,1
#
# radioscandalo,DeQueValeAmar,2
#
# radioscandalo,NotaCuriosa,1
#
# radioscandalo,PeppaPig,1
#
# radioscandalo,ManUtd,6
#
# radioscandalo,SuperdificialEcuador,1
#
# radioscandalo,Mexico,2
#
# radioscandalo,RUSIA2018,1
#
# radioscandalo,FelipeCaicedo,1
#
# radioscandalo,EspectroParty,1
#
# radioscandalo,LeySolidaria,1
#
# radioscandalo,CopaSudamericana,16
#
# radioscandalo,Medios,1
#
# radioscandalo,Virgen,1
#
# radioscandalo,Colombia,15
#
# radioscandalo,MantFc,1
#
# radioscandalo,Ginza,1
#
# radioscandalo,TecUni,10
#
# radioscandalo,Lima,2
#
# radioscandalo,ElNacional,6
#
# radioscandalo,DepQuito,3
#
# radioscandalo,Sevilla,2
#
# radioscandalo,FuerzaManabi,2
#
# radioscandalo,LigaBBVA,2
#
# radioscandalo,LigaDePortoviejo,1
#
# radioscandalo,SeleccionEcuador,1
#
# radioscandalo,NorteAmerica,1
#
# radioscandalo,Refuerzos,1
#
# radioscandalo,manabaqueserespeta,1
#
# radioscandalo,LaMangaDelCuraEsManabita,1
#
# radioscandalo,BryanSanchez,1
#
# radioscandalo,LaBramadora,2
#
# radioscandalo,Aucas,1
#
# radioscandalo,River,1
#
# radioscandalo,Barelona,1
#
# radioscandalo,envivo,1
#
# radioscandalo,Montecristi,2
#
# radioscandalo,Gualaceo,10
#
# radioscandalo,JornadaPorLaNinez,1
#
# radioscandalo,Politicos,1
#
# radioscandalo,Enlace402,1
#
# radioscandalo,Venezuela,5
#
# radioscandalo,reinademanabi,1
#
# radioscandalo,Entradas,1
#
# radioscandalo,Wolfsburgo,4
#
# radioscandalo,GustavoQuinteros,2
#
# radioscandalo,puntocaramelo,2
#
# radioscandalo,clasico,1
#
# radioscandalo,Doki,1
#
# radioscandalo,VivaQuito,1
#
# radioscandalo,Bomberos,3
#
# radioscandalo,GUALACEO,1
#
# radioscandalo,Futsal,54
#
# radioscandalo,Ecu911Contigo,2
#
# radioscandalo,Guayaquil,3
#
# radioscandalo,Rusia2018,1
#
# radioscandalo,deportemanaba,1
#
# radioscandalo,elecciones2014,2
#
# radioscandalo,TerminalTerrestre,1
#
# radioscandalo,FreyerMendoza,1
#
# radioscandalo,Policia,4
#
# radioscandalo,EstadioJocay,2
#
# radioscandalo,NoticiaEnDesarrollo,1
#
# radioscandalo,Barcelona,12
#
# radioscandalo,TodosSomosPais,1
#
# radioscandalo,idolomanabi,1
#
# radioscandalo,RealMadrid,3
#
# radioscandalo,Copa,1
#
# radioscandalo,TitoVicuna,1
#
# radioscandalo,ATodoPulmon,1
#
# radioscandalo,QuizasManana,1
#
# radioscandalo,SerieB,6
#
# radioscandalo,Manta,9
#
# radioscandalo,ECU911,1
#
# radioscandalo,EMELEC,4
#
# radioscandalo,RDM2015,1
#
# radioscandalo,Unidad,1
#
# radioscandalo,Azogues,1
#
# radioscandalo,ELIMINATORIAS,1
#
# radioscandalo,Suma23,1
#
# radioscandalo,Rafanatica,1
#
# radioscandalo,GabrielMarques,1
#
# radioscandalo,FestivalAcrobaticoPortoviejo,1
#
# radioscandalo,DelfinSc,1
#
# radioscandalo,MarianoZambrano,1
#
# radioscandalo,ElCarmen,5
#
# radioscandalo,FAmarilla,8
#
# radioscandalo,CopaLibertadores,2
#
# radioscandalo,ChampionsLeague,4
#
# radioscandalo,Olmedo,4
#
# radioscandalo,CarlosTevez,1
#
# radioscandalo,emergencia,1
#
# radioscandalo,YaTeOlvide,1
#
# radioscandalo,EstrenoMundial,1
#
# radioscandalo,CHILE,2
#
# radioscandalo,LunaLlena,2
#
# radioscandalo,MatiasOyola,1
#
# radioscandalo,Dominguez,1
#
# radioscandalo,RetornoSeguro,2
#
# radioscandalo,IndDelValle,1
#
# radioscandalo,RendicionDeCuentasGPM,1
#
# radioscandalo,Lasso,1

# %%
df = pd.read_csv("../Outputs/frequencies.csv")
df.head()
# Out:
#   File "<ipython-input-81-846a14394410>", line 3
#     df["average"]=
#                   ^
# SyntaxError: invalid syntax

# %%
df["norm_rt_activity"]= df["num_rts"]/df["num_vtweets"]
df.head()

df["norm_fav_activity"]= df["num_favs"]/df["num_vtweets"]
ds = df[["user","norm_rt_activity","norm_fav_activity"]] 
ds.set_index(["user"],inplace=True)
ds.plot(kind='scatter',alpha=0.75, rot=90)
print ds.head()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-82-daacbf6aea63> in <module>()
# ----> 1 df["norm_rt_activity"]= df["num_rts"]/df["num_vtweets"]
#       2 df.head()
#       3
#       4 df["norm_fav_activity"]= df["num_favs"]/df["num_vtweets"]
#       5 ds = df[["user","norm_rt_activity","norm_fav_activity"]]
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1962             return self._getitem_multilevel(key)
#    1963         else:
# -> 1964             return self._getitem_column(key)
#    1965
#    1966     def _getitem_column(self, key):
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    1969         # get column
#    1970         if self.columns.is_unique:
# -> 1971             return self._get_item_cache(key)
#    1972
#    1973         # duplicate columns & possible reduce dimensionality
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1643         res = cache.get(item)
#    1644         if res is None:
# -> 1645             values = self._data.get(item)
#    1646             res = self._box_item_values(item, values)
#    1647             cache[item] = res
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/internals.pyc in get(self, item, fastpath)
#    3588
#    3589             if not isnull(item):
# -> 3590                 loc = self.items.get_loc(item)
#    3591             else:
#    3592                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/indexes/base.pyc in get_loc(self, key, method, tolerance)
#    2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
# -> 2444                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2445
#    2446         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5280)()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5126)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20523)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20477)()
#
# KeyError: 'num_rts'

# %%
import seaborn as sns
par = sns.pairplot(ds)
plt.show()

# %%
import unicodedata
def elimina_tildes(s):
   return ''.join((c for c in unicodedata.normalize('NFD', s) if unicodedata.category(c) != 'Mn'))
 
print elimina_tildes(u"cóñrcholis")
# Out:
# conrcholis

# %%
import seaborn as sns
df = pd.read_csv("../Outputs/mentions.csv")
ds = df[df["weight"]>5]
ds.to_csv("../Outputs/mentions_plus5.csv")

# %%
f = open("../Outputs/mentions_plus5.csv")
nodes = set()
for line in f:
    id, source,target, freq = line.split(",")
    nodes.add(source)
    nodes.add(target)
f.close()
f = open("../Outputs/nodes_mentions_plus5.csv","w")
f.write("id,label\n")
for element in nodes:
    f.write("%s,%s\n"%(element,element))
f.close()

# %%
import time
from datetime import datetime
import pytz
from email.utils import parsedate_tz, mktime_tz

def isRetweet(tweet):
	texto = tweet['text']
	if 'retweeted_status' in tweet or (len(texto) > 4 and texto[:4] == 'RT @'):
		return True
	return False

def getRetweetCount(tweet):
	return tweet['retweet_count']

def getFavoriteCount(tweet):
	return tweet['favorite_count']

def fillWeekHours(user_info):
    for day in user_info['days']:
        for month in range(1,13):
            user_info['days'][day][month] = {}
            for hour in range(24):
                user_info['days'][day][month][hour] = {}
                user_info['days'][day][month][hour]['retweet_count'] = 0
                user_info['days'][day][month][hour]['favorite_count'] = 0

def get_num_tweets(filen):
    d = json.loads(open(path+filen).read())
    result = d["num_tweets"]
    for t in d["tweets"]:
        if not isValid(t) or isRetweet(t):
            result = result -1
    return result
            
def getUsersWeeklyHourData(users_list):

	f = open('users_basic_data1.csv', 'w')
	f.write('username,retweet_count,favorite_count,num_tweets,month,day,hour\n')
	for username in users_list:
		user_info = { 'days': {0:{}, 1:{}, 2:{}, 3:{}, 4:{}, 5:{}, 6:{}}}
		user_info['username'] = username
		fillWeekHours(user_info)
		user_data = json.loads(open(path+username).read())
		tweets = user_data['tweets']
        user_info["num_tweets"] = get_num_tweets(username)
        for tweet in tweets:
            timestamp = mktime_tz(parsedate_tz(tweet['created_at']))
            dt = datetime.fromtimestamp(timestamp, pytz.timezone('US/Central'))
            weekday = dt.weekday()
            hour = dt.hour
            month = dt.month
            if not isRetweet(tweet):
                user_info['days'][weekday][month][hour]['retweet_count'] += getRetweetCount(tweet)
                user_info['days'][weekday][month][hour]['favorite_count'] += getFavoriteCount(tweet)
            writeUserWeeklyHourData(user_info, f)
        f.close()

def writeUserWeeklyHourData(user_info, f):
	username = user_info['username']
	for day in user_info['days']:
		for month in user_info['days'][day]:
			for hour in user_info['days'][day][month]:
				retweet_count = user_info['days'][day][month][hour]['retweet_count']
				favorite_count = user_info['days'][day][month][hour]['favorite_count']
				f.write(username + ',' + str(retweet_count) + ',' + str(favorite_count) + ','+ str(user_info["num_tweets"]))
				f.write(str(month) + ',' + str(day) + ',' + str(hour) + '\n')

getUsersWeeklyHourData(fils)

# %%
de = pd.read_csv("users_basic_data.csv")
de["username"] = de["username"].apply(lambda x: x.split(".")[0])

# %%
dist = de.groupby(["month"]).sum()[["retweet_count"]]
dist.plot()
plt.show()

# %%
aceptacion = de.groupby(["username"]).sum()[["retweet_count","favorite_count"]]
# Out:
#                  retweet_count  favorite_count
# username
# 35apmanta                 1184             614
# APortuariaManta           4649            3166
# AeropuertoManta            190              79
# AguasdeManta              1654            1491
# AnaMa_suarez              1091            1564
# ArielTravelMant             15              10
# CNEManabi                 2080            1486
# DiarioelManaba             263             203
# ECU911PVO                 8179            5431
# FERRUZAM                    53               3
# GADManabi               152237           36190
# Gerardo_Manta               27              21
# GoberManabi              54721           29082
# HRZManta                  6455            4783
# Isaintriagomo             2549            1925
# JPAISManta                   1               0
# JosRHerreraF1              414             477
# JuvenManabi                197              80
# KarlaCadena35            32524           19235
# LaMareaec                 1100            1763
# LadyGarciaMejia             41              89
# MIES_Zona4               96402           14626
# ManabiCJ                 12291            6927
# ManabitaEnTrova            230             197
# MantaDigital                38               3
# MantaMunicipio             245              34
# MantaToday                 259             278
# MarianoEsManabi          33057           14077
# Municipio_Manta           4587            5290
# PatronatoManta            3955            3784
# ...                        ...             ...
# diazfabr                  2322            1328
# eddercuero                4427             895
# eldiarioec                3613            5466
# elmercuriomanta              2               3
# fabriciomanabi             263             202
# jorgezamb1                6278            5957
# joronues                    53              46
# joseleemsgm                  0               0
# mabe_santos               2815            2602
# manavisionec               765            1005
# manta360                    94              17
# mantaOnLine                437             239
# mireza13                   206             147
# nitidomkt                  348              18
# oromartv                  5353            5925
# pastoralvia                  2               3
# pedroloaizaf                 5               7
# qhacer_manabi             1850            2333
# radioMarejada              645             211
# radiocanaveral9           1667             695
# radioscandalo              428             219
# revistademanabi            251             135
# ricardozampais            8098            6769
# smontenegro2923          11478            8055
# stefanymaciass             149             165
# ttmanta                     89              83
# tvmanabita                 232             281
# vchiribogae                416              92
# veronicabad               7976            7046
# yoManaba                   270             394
#
# [80 rows x 2 columns]

# %%
aceptacion.value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-191-3c9b6012d26e> in <module>()
# ----> 1 aceptacion.value_counts()
#
# NameError: name 'aceptacion' is not defined

# %%
q=de.groupby(["month","day"]).sum().loc[(10,)]

# %%
del q["hour"]

# %%
import pylab
q.plot(kind='line')

plt.savefig('oct.png')

# %%
de
# Out:
#             username  retweet_count  favorite_count  month  day  hour
# 0       manavisionec              0               0      1    0     0
# 1       manavisionec              0               0      1    0     1
# 2       manavisionec              0               0      1    0     2
# 3       manavisionec              0               0      1    0     3
# 4       manavisionec              0               0      1    0     4
# 5       manavisionec              0               0      1    0     5
# 6       manavisionec              0               0      1    0     6
# 7       manavisionec              0               0      1    0     7
# 8       manavisionec              0               0      1    0     8
# 9       manavisionec              0               0      1    0     9
# 10      manavisionec              0               0      1    0    10
# 11      manavisionec              0               0      1    0    11
# 12      manavisionec              0               0      1    0    12
# 13      manavisionec              0               0      1    0    13
# 14      manavisionec              0               0      1    0    14
# 15      manavisionec              0               0      1    0    15
# 16      manavisionec              0               0      1    0    16
# 17      manavisionec              0               0      1    0    17
# 18      manavisionec              0               0      1    0    18
# 19      manavisionec              0               0      1    0    19
# 20      manavisionec              0               0      1    0    20
# 21      manavisionec              0               0      1    0    21
# 22      manavisionec              0               0      1    0    22
# 23      manavisionec              0               0      1    0    23
# 24      manavisionec              0               0      2    0     0
# 25      manavisionec              0               0      2    0     1
# 26      manavisionec              0               0      2    0     2
# 27      manavisionec              0               0      2    0     3
# 28      manavisionec              0               0      2    0     4
# 29      manavisionec              0               0      2    0     5
# ...              ...            ...             ...    ...  ...   ...
# 161250      diazfabr              0               0     11    6    18
# 161251      diazfabr              0               0     11    6    19
# 161252      diazfabr              0               0     11    6    20
# 161253      diazfabr              0               0     11    6    21
# 161254      diazfabr              0               0     11    6    22
# 161255      diazfabr              0               0     11    6    23
# 161256      diazfabr              0               0     12    6     0
# 161257      diazfabr              0               0     12    6     1
# 161258      diazfabr              0               0     12    6     2
# 161259      diazfabr              0               0     12    6     3
# 161260      diazfabr              0               0     12    6     4
# 161261      diazfabr              0               0     12    6     5
# 161262      diazfabr              0               0     12    6     6
# 161263      diazfabr              0               0     12    6     7
# 161264      diazfabr              0               0     12    6     8
# 161265      diazfabr              0               0     12    6     9
# 161266      diazfabr              0               0     12    6    10
# 161267      diazfabr              0               0     12    6    11
# 161268      diazfabr              0               0     12    6    12
# 161269      diazfabr              0               0     12    6    13
# 161270      diazfabr              0               0     12    6    14
# 161271      diazfabr              0               0     12    6    15
# 161272      diazfabr              0               0     12    6    16
# 161273      diazfabr              0               0     12    6    17
# 161274      diazfabr              0               0     12    6    18
# 161275      diazfabr              0               0     12    6    19
# 161276      diazfabr              0               0     12    6    20
# 161277      diazfabr              0               0     12    6    21
# 161278      diazfabr              0               0     12    6    22
# 161279      diazfabr              0               0     12    6    23
#
# [161280 rows x 6 columns]
